# %% [markdown]
# # Acquisition Data Preparation: Completed Deals
# Here we obtain data for deals which were executed but the target company continued to operate as an independent entity.

# %%
import lseg.data as ld
from lseg.data.content import search
import pandas as pd
from datetime import datetime, timedelta
from IPython.display import display, HTML
import re

# %%
# To get organization metadata
ld.open_session()

response = search.metadata.Definition(
    view = search.Views.ORGANISATIONS  # Required parameterc
).get_data()


# Set display options to print the entire DataFrame
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full content in each cell

# Now, print the entire DataFrame
print(response.data.df)

# Reset display options if you don't want this setting to persist
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.max_colwidth')
# Out:
#                                                                                               Type  \
# ActiveDebtInstrumentCount                    ActiveDebtInstrumentCount                      Double
# ActiveEquityInstrumentCount                  ActiveEquityInstrumentCount                    Double
# ActiveEstimatesExist                         ActiveEstimatesExist                          Boolean
# ActiveInstrumentCount                        ActiveInstrumentCount                          Double
# AddressCity                                  AddressCity                                    String
# AddressLine1                                 AddressLine1                                   String
# AddressLine1Ja                               AddressLine1Ja                                 String
# AddressLine1Zh                               AddressLine1Zh                                 String
# AddressLine2                                 AddressLine2                                   String
# AddressLine2Ja                               AddressLine2Ja                                 String
# AddressLine2Zh                               AddressLine2Zh                                 String
# AddressLine3                                 AddressLine3                                   String
# AddressLine3Ja                               AddressLine3Ja                                 String
# AddressLine3Zh                               AddressLine3Zh                                 String
# AddressLine4                                 AddressLine4                                   String
# AddressLine4Ja                               AddressLine4Ja                                 String
# AddressLine4Zh                               AddressLine4Zh                                 String
# AddressLine5                                 AddressLine5                                   String
# AddressLine5Ja                               AddressLine5Ja                                 String
# AddressLine5Zh                               AddressLine5Zh                                 String
# AddressPostalCode                            AddressPostalCode                              String
# AddressStateProvince                         AddressStateProvince                           String
# AddressStateProvinceOfficialCode             AddressStateProvinceOfficialCode               String
# AdminStatus                                  AdminStatus                                    String
# AlternateLegalName                           AlternateLegalName                             String
# AverageSharesOutstanding                     AverageSharesOutstanding                       Double
# BondsCount                                   BondsCount                                     Double
# BuildDateTime                                BuildDateTime                                    Date
# BusinessDescription                          BusinessDescription                            String
# BusinessEntity                               BusinessEntity                                 String
# BusinessIntelligenceExists                   BusinessIntelligenceExists                    Boolean
# CalaisAlias                                  CalaisAlias                                    String
# CapitalRatioTier1                            CapitalRatioTier1                              Double
# CashAndEquivalents                           CashAndEquivalents                             Double
# CdsCount                                     CdsCount                                       Double
# CdsUltimateParentCount                       CdsUltimateParentCount                         Double
# CertificatesOfDepositCount                   CertificatesOfDepositCount                     Double
# CIK                                          CIK                                            String
# ClaimsRatio                                  ClaimsRatio                                    Double
# CommercialPaperCount                         CommercialPaperCount                           Double
# CommonAddressLine1                           CommonAddressLine1                             String
# CommonAddressLine2                           CommonAddressLine2                             String
# CommonAddressLine3                           CommonAddressLine3                             String
# CommonAddressLine4                           CommonAddressLine4                             String
# CommonAddressLine5                           CommonAddressLine5                             String
# CommonName                                   CommonName                                     String
# CommonNameJaHani                             CommonNameJaHani                               String
# CommonNameJaHira                             CommonNameJaHira                               String
# CommonNameJaKana                             CommonNameJaKana                               String
# CommonNameOther                              CommonNameOther                                String
# CommonNameZhHans                             CommonNameZhHans                               String
# CommonNameZhHant                             CommonNameZhHant                               String
# CompanyDataStreamID                          CompanyDataStreamID                            String
# CompanyOfficers                              CompanyOfficers                                String
# ContributorCode                              ContributorCode                                String
# CostIncomeRatio                              CostIncomeRatio                                Double
# CostOfSales                                  CostOfSales                                    Double
# CountryHeadquarters                          CountryHeadquarters                            String
# CountryHeadquartersName                      CountryHeadquartersName                        String
# CPERMIDs                                     CPERMIDs                                       String
# CurrentAssets                                CurrentAssets                                  Double
# CurrentLiabilities                           CurrentLiabilities                             Double
# CurrentRatio                                 CurrentRatio                                   Double
# DatastreamFIID                               DatastreamFIID                                 String
# DebtToAssets                                 DebtToAssets                                   Double
# DebtToEquity                                 DebtToEquity                                   Double
# DelayedQuoteRIC                              DelayedQuoteRIC                                String
# DelistedDate                                 DelistedDate                                   String
# DisclosureIDs                                DisclosureIDs                                  String
# DjStoxx                                      DjStoxx                                        String
# DocumentsExist                               DocumentsExist                                Boolean
# DocumentTitle                                DocumentTitle                                  String
# DocumentTitleJaHani                          DocumentTitleJaHani                            String
# DocumentTitleJaHira                          DocumentTitleJaHira                            String
# DocumentTitleJaKana                          DocumentTitleJaKana                            String
# DocumentTitleKo                              DocumentTitleKo                                String
# DocumentTitleZhHans                          DocumentTitleZhHans                            String
# DocumentTitleZhHant                          DocumentTitleZhHant                            String
# DoingBusinessAsNames                         DoingBusinessAsNames                           String
# DTCCVolumeRIC                                DTCCVolumeRIC                                  String
# DTCharacteristics                            DTCharacteristics                              String
# DTSimpleType                                 DTSimpleType                                   String
# DTSubjectName                                DTSubjectName                                  String
# DTSubjectNameJaHani                          DTSubjectNameJaHani                            String
# DTSubjectNameJaHira                          DTSubjectNameJaHira                            String
# DTSubjectNameJaKana                          DTSubjectNameJaKana                            String
# DTSubjectNameKo                              DTSubjectNameKo                                String
# DTSubjectNameZhHans                          DTSubjectNameZhHans                            String
# DTSubjectNameZhHant                          DTSubjectNameZhHant                            String
# Ebit                                         Ebit                                           Double
# Ebitda                                       Ebitda                                         Double
# Edcoid                                       Edcoid                                         String
# EdcoidPI                                     EdcoidPI                                       String
# EdcoidQuotePI                                EdcoidQuotePI                                  String
# EEDBID                                       EEDBID                                         String
# EquitiesCount                                EquitiesCount                                  Double
# EquityDividends                              EquityDividends                                Double
# EquityIndices                                EquityIndices                                  String
# EquityInstrumentsCount                       EquityInstrumentsCount                         Double
# EquityIssued                                 EquityIssued                                   Double
# EstimatesExist                               EstimatesExist                                Boolean
# Ev                                           Ev                                             Double
# ExpenseRatio                                 ExpenseRatio                                   Double
# ExpiredRIC                                   ExpiredRIC                                     String
# FDS                                          FDS                                            String
# FilingsExist                                 FilingsExist                                  Boolean
# FitchIssuerRating                            FitchIssuerRating                              String
# FormerlyKnownAsNames                         FormerlyKnownAsNames                           String
# FormOfTransactionCode                        FormOfTransactionCode                          String
# FoundedOnDate                                FoundedOnDate                                    Date
# FtseScheme                                   FtseScheme                                     String
# FundamentalsExist                            FundamentalsExist                             Boolean
# FundsCount                                   FundsCount                                     Double
# FuturesCount                                 FuturesCount                                   Double
# GEMAlphaNumericID                            GEMAlphaNumericID                              String
# GEMPermID                                    GEMPermID                                      String
# GeneralAliasName                             GeneralAliasName                               String
# GeneralAliasNameJaHani                       GeneralAliasNameJaHani                         String
# GeneralAliasNameJaHira                       GeneralAliasNameJaHira                         String
# GeneralAliasNameJaKana                       GeneralAliasNameJaKana                         String
# GeneralAliasNameZhHans                       GeneralAliasNameZhHans                         String
# GeneralAliasNameZhHant                       GeneralAliasNameZhHant                         String
# Gics                                         Gics                                           String
# GicsCode                                     GicsCode                                       String
# GicsIndustryID                               GicsIndustryID                                 String
# GicsLeaf                                     GicsLeaf                                       String
# GicsName                                     GicsName                                       String
# HasBusinessDescriptionInVFDB                 HasBusinessDescriptionInVFDB                  Boolean
# HasDeals                                     HasDeals                                      Boolean
# HasESGContent                                HasESGContent                                 Boolean
# HasFinancialsInVFDB                          HasFinancialsInVFDB                           Boolean
# HasIndustryCodeInVFDB                        HasIndustryCodeInVFDB                         Boolean
# HasOwnership                                 HasOwnership                                  Boolean
# HasPEOwnership                               HasPEOwnership                                Boolean
# HasProfileInVFDB                             HasProfileInVFDB                              Boolean
# HasTRF                                       HasTRF                                        Boolean
# HasTRFBS                                     HasTRFBS                                      Boolean
# HasTRFCS                                     HasTRFCS                                      Boolean
# HasTRFIS                                     HasTRFIS                                      Boolean
# HKAlias                                      HKAlias                                        String
# HKVersion                                    HKVersion                                      String
# ICBScheme                                    ICBScheme                                      String
# ICBSchemeName                                ICBSchemeName                                  String
# InactiveDate                                 InactiveDate                                     Date
# InactiveDay                                  InactiveDay                                    String
# InactiveMonth                                InactiveMonth                                  String
# InactiveYear                                 InactiveYear                                   String
# IndicesCount                                 IndicesCount                                   Double
# IndustryClassificationBenchmark              IndustryClassificationBenchmark                String
# InsertDateTime                               InsertDateTime                                   Date
# InterestCover                                InterestCover                                  Double
# InterimNetIncome                             InterimNetIncome                               Double
# InvestmentCertificateCount                   InvestmentCertificateCount                     Double
# InvestorAddressCity                          InvestorAddressCity                            String
# InvestorAddressCountry                       InvestorAddressCountry                         String
# InvestorContactFirstName                     InvestorContactFirstName                       String
# InvestorContactLastName                      InvestorContactLastName                        String
# InvestorContactName                          InvestorContactName                            String
# InvestorEquityAssets                         InvestorEquityAssets                           Double
# InvestorFullName                             InvestorFullName                               String
# InvestorInvestmentStyle                      InvestorInvestmentStyle                        String
# InvestorLatestFilingDate                     InvestorLatestFilingDate                         Date
# InvestorOrientation                          InvestorOrientation                            String
# InvestorParentType                           InvestorParentType                             String
# InvestorSubType                              InvestorSubType                                String
# InvestorTurnover                             InvestorTurnover                               String
# IPODate                                      IPODate                                          Date
# IsActive                                     IsActive                                      Boolean
# IsCapitalMarketsActive                       IsCapitalMarketsActive                        Boolean
# IsContributor                                IsContributor                                 Boolean
# IsExchange                                   IsExchange                                    Boolean
# IsFirm                                       IsFirm                                        Boolean
# IsFundSupportCompany                         IsFundSupportCompany                          Boolean
# IsIndexConstituent                           IsIndexConstituent                            Boolean
# IsMainCompanyFiling                          IsMainCompanyFiling                           Boolean
# IsMainIssueFiling                            IsMainIssueFiling                             Boolean
# IsOrganizationManaged                        IsOrganizationManaged                         Boolean
# IsOrganizationVerified                       IsOrganizationVerified                        Boolean
# IsPreIPO                                     IsPreIPO                                      Boolean
# IsPublic                                     IsPublic                                      Boolean
# IsShariahCompliant                           IsShariahCompliant                            Boolean
# IssuerBondsExist                             IssuerBondsExist                              Boolean
# IssuerCikNumber                              IssuerCikNumber                                String
# IssuerEquityPrimaryRIC                       IssuerEquityPrimaryRIC                         String
# IssuerHasCds                                 IssuerHasCds                                  Boolean
# IssuerID                                     IssuerID                                       String
# IssuersUltimateParentHasCDS                  IssuersUltimateParentHasCDS                   Boolean
# IssuersUltimateParentIssuerID                IssuersUltimateParentIssuerID                  String
# IssuersUltimateParentREC                     IssuersUltimateParentREC                       String
# IsTRACEEligible                              IsTRACEEligible                               Boolean
# LegalName                                    LegalName                                      String
# LegalNameJaHani                              LegalNameJaHani                                String
# LegalNameJaHira                              LegalNameJaHira                                String
# LegalNameJaKana                              LegalNameJaKana                                String
# LegalNameLanguage                            LegalNameLanguage                              String
# LegalNameZhHans                              LegalNameZhHans                                String
# LegalNameZhHant                              LegalNameZhHant                                String
# LEI                                          LEI                                            String
# LipperID                                     LipperID                                       String
# LiquidityRIC                                 LiquidityRIC                                   String
# ListingStatus                                ListingStatus                                  String
# ListingStatusName                            ListingStatusName                              String
# LoanCount                                    LoanCount                                      Double
# LocalScheme                                  LocalScheme                                    String
# LongName                                     LongName                                       String
# LongNameJaHani                               LongNameJaHani                                 String
# LongNameKo                                   LongNameKo                                     String
# LongNameZhHans                               LongNameZhHans                                 String
# LongNameZhHant                               LongNameZhHant                                 String
# LongTermDebt                                 LongTermDebt                                   Double
# MainFilingCommonName                         MainFilingCommonName                           String
# MainFilingType                               MainFilingType                                 String
# MarkItShortName                              MarkItShortName                                String
# MktCapCompanyUsd                             MktCapCompanyUsd                               Double
# MnaAcquirerCount                             MnaAcquirerCount                               Double
# MnaParentAcquirerCount                       MnaParentAcquirerCount                         Double
# MnaParentTargetCount                         MnaParentTargetCount                           Double
# MnaSellerCount                               MnaSellerCount                                 Double
# MnaTargetCount                               MnaTargetCount                                 Double
# MoodysIssuerRating                           MoodysIssuerRating                             String
# MortgagesCount                               MortgagesCount                                 Double
# MsciGicsLocalScheme                          MsciGicsLocalScheme                            String
# MultexIndustryClassification                 MultexIndustryClassification                   String
# MXID                                         MXID                                           String
# Nd                                           Nd                                             Double
# NDAPI                                        NDAPI                                          String
# NetInterestMargin                            NetInterestMargin                              Double
# NetProfit                                    NetProfit                                      Double
# NetProfitUsd                                 NetProfitUsd                                   Double
# NumberOfEmployees                            NumberOfEmployees                              Double
# OAOrganizationSubType                        OAOrganizationSubType                          String
# OAOrganizationType                           OAOrganizationType                             String
# OAOrgSubType                                 OAOrgSubType                                   String
# OAOrgSubTypeName                             OAOrgSubTypeName                               String
# OAOrgType                                    OAOrgType                                      String
# OAOrgTypeName                                OAOrgTypeName                                  String
# OAPermID                                     OAPermID                                       String
# OfficersExist                                OfficersExist                                 Boolean
# OldRIC                                       OldRIC                                         String
# OpMargin                                     OpMargin                                       Double
# OpProfit                                     OpProfit                                       Double
# OpProfitInterim                              OpProfitInterim                                Double
# OpProfitUsd                                  OpProfitUsd                                    Double
# OpRatio                                      OpRatio                                        Double
# OptionsCount                                 OptionsCount                                   Double
# OrganisationNodeType                         OrganisationNodeType                           String
# OrganisationStatus                           OrganisationStatus                             String
# OrganisationType                             OrganisationType                               String
# OrganisationTypeName                         OrganisationTypeName                           String
# OrganizationAddressPostalCode                OrganizationAddressPostalCode                  String
# OrganizationAddressStateProvince             OrganizationAddressStateProvince               String
# OrganizationAddressStateProvinceOfficialCode OrganizationAddressStateProvinceOfficialCode   String
# OrganizationCity                             OrganizationCity                               String
# OrganizationWebsite                          OrganizationWebsite                            String
# Orgid                                        Orgid                                          String
# OrgMainRepno                                 OrgMainRepno                                   String
# OriginalAccountsCurrency                     OriginalAccountsCurrency                       String
# OriginalRIC                                  OriginalRIC                                    String
# OwnershipExists                              OwnershipExists                               Boolean
# ParentCompanyGEMPermID                       ParentCompanyGEMPermID                         String
# ParentCompanyNDAPI                           ParentCompanyNDAPI                             String
# ParentCompanyOAPermID                        ParentCompanyOAPermID                          String
# ParentCompanyPI                              ParentCompanyPI                                String
# ParentOrganisationName                       ParentOrganisationName                         String
# ParentOrganisationNameJaHani                 ParentOrganisationNameJaHani                   String
# ParentOrganisationOrgid                      ParentOrganisationOrgid                        String
# ParentType                                   ParentType                                     String
# PEBackedStatus                               PEBackedStatus                                 String
# PercentageIndexRIC                           PercentageIndexRIC                             String
# PI                                           PI                                             String
# PreferenceSharesCount                        PreferenceSharesCount                          Double
# PreferredStockDividends                      PreferredStockDividends                        Double
# PretaxProfit                                 PretaxProfit                                   Double
# PretaxProfitInterim                          PretaxProfitInterim                            Double
# PretaxProfitMargin                           PretaxProfitMargin                             Double
# PretaxProfitUsd                              PretaxProfitUsd                                Double
# PreviousNames                                PreviousNames                                  String
# PrimaryInstrumentPI                          PrimaryInstrumentPI                            String
# PrimaryIssueName                             PrimaryIssueName                               String
# PrimaryIssuePILC                             PrimaryIssuePILC                               String
# PrimaryIssueRIC                              PrimaryIssueRIC                                String
# PrimaryRIC                                   PrimaryRIC                                     String
# PrimaryRICCinCUSIP                           PrimaryRICCinCUSIP                             String
# PrimaryRICCUSIP                              PrimaryRICCUSIP                                String
# PrimaryRICExchangeCode                       PrimaryRICExchangeCode                         String
# PrimaryRICExchangeName                       PrimaryRICExchangeName                         String
# PrimaryRICISIN                               PrimaryRICISIN                                 String
# PrimaryRICPI                                 PrimaryRICPI                                   String
# PrimaryRICRCSAssetCategory                   PrimaryRICRCSAssetCategory                     String
# PrimaryRICRCSAssetCategoryLeaf               PrimaryRICRCSAssetCategoryLeaf                 String
# PrimaryRICRICAcctsCount                      PrimaryRICRICAcctsCount                        Double
# PrimaryRICRICUsageCount                      PrimaryRICRICUsageCount                        Double
# PrimaryRICSEDOL                              PrimaryRICSEDOL                                String
# PrimaryRICTickerSymbol                       PrimaryRICTickerSymbol                         String
# PrimaryTradedQuotePI                         PrimaryTradedQuotePI                           String
# QuickRatio                                   QuickRatio                                     Double
# QuoteDsQuotationMnemonics                    QuoteDsQuotationMnemonics                      String
# QuoteDsQuotationNumbers                      QuoteDsQuotationNumbers                        String
# QuoteIlxIds                                  QuoteIlxIds                                    String
# QuoteRICs                                    QuoteRICs                                      String
# QuoteSEDOLs                                  QuoteSEDOLs                                    String
# QuoteTickers                                 QuoteTickers                                   String
# RankDateTime                                 RankDateTime                                     Date
# RatingOutlookRank                            RatingOutlookRank                              String
# RatingPreliminary                            RatingPreliminary                              String
# RatingRank                                   RatingRank                                     String
# RatingScopeRank                              RatingScopeRank                                String
# RatingsExist                                 RatingsExist                                  Boolean
# RatingsScope                                 WatchCodeRank                                 Integer
#                                              Preliminary                                    String
#                                              Agency                                         String
#                                              CurrentRating                                  String
#                                              RatingType                                     String
#                                              Outlook                                        String
#                                              CurrentRatingDate                                Date
#                                              PreviousRatingDate                               Date
#                                              WatchCode                                      String
#                                              WatchEffectiveDate                               Date
#                                              CurrentRatingRank                             Integer
#                                              PreviousRating                                 String
#                                              Solicited                                      String
#                                              PreviousRatingRank                            Integer
#                                              OutlookRank                                   Integer
#                                              RatingScope                                    String
#                                              OutlookEffectiveDate                             Date
#                                              RatingsScope                                   Nested
# RatingType                                   RatingType                                     String
# RatingWatchCodeRank                          RatingWatchCodeRank                            String
# RbssScheme                                   RbssScheme                                     String
# RbssSchemeCode                               RbssSchemeCode                                 String
# RCSCountryHeadquarters                       RCSCountryHeadquarters                         String
# RCSCountryHeadquartersGenealogy              RCSCountryHeadquartersGenealogy                String
# RCSCountryHeadquartersLeaf                   RCSCountryHeadquartersLeaf                     String
# RCSCountryHeadquartersLeafML                 RCSCountryHeadquartersLeafML                   String
# RCSCountryHeadquartersName                   RCSCountryHeadquartersName                     String
# RCSCountryHeadquartersNameML                 RCSCountryHeadquartersNameML                   String
# RCSCountryOfIncorporation                    RCSCountryOfIncorporation                      String
# RCSCountryOfIncorporationGenealogy           RCSCountryOfIncorporationGenealogy             String
# RCSCountryOfIncorporationLeaf                RCSCountryOfIncorporationLeaf                  String
# RCSFilingCountry                             RCSFilingCountry                               String
# RCSFilingCountryGenealogy                    RCSFilingCountryGenealogy                      String
# RCSFilingCountryLeaf                         RCSFilingCountryLeaf                           String
# RCSFilingCountryLeafML                       RCSFilingCountryLeafML                         String
# RCSFilingCountryName                         RCSFilingCountryName                           String
# RCSFilingCountryNameML                       RCSFilingCountryNameML                         String
# RCSFilingCurrencyName                        RCSFilingCurrencyName                          String
# RCSOrganisationSubType                       RCSOrganisationSubType                         String
# RCSOrganisationSubTypeGenealogy              RCSOrganisationSubTypeGenealogy                String
# RCSOrganisationSubTypeLeaf                   RCSOrganisationSubTypeLeaf                     String
# RCSOrganisationSubTypeLeafML                 RCSOrganisationSubTypeLeafML                   String
# RCSOrganisationSubTypeName                   RCSOrganisationSubTypeName                     String
# RCSOrganisationSubTypeNameML                 RCSOrganisationSubTypeNameML                   String
# RCSOrganisationType                          RCSOrganisationType                            String
# RCSOrganisationTypeGenealogy                 RCSOrganisationTypeGenealogy                   String
# RCSOrganisationTypeLeaf                      RCSOrganisationTypeLeaf                        String
# RCSOrganisationTypeLeafML                    RCSOrganisationTypeLeafML                      String
# RCSOrganisationTypeName                      RCSOrganisationTypeName                        String
# RCSOrganisationTypeNameML                    RCSOrganisationTypeNameML                      String
# RCSOriginalAccountsCurrency                  RCSOriginalAccountsCurrency                    String
# RCSOriginalAccountsCurrencyGenealogy         RCSOriginalAccountsCurrencyGenealogy           String
# RCSOriginalAccountsCurrencyLeaf              RCSOriginalAccountsCurrencyLeaf                String
# RCSOriginalAccountsCurrencyLeafML            RCSOriginalAccountsCurrencyLeafML              String
# RCSOriginalAccountsCurrencyName              RCSOriginalAccountsCurrencyName                String
# RCSOriginalAccountsCurrencyNameML            RCSOriginalAccountsCurrencyNameML              String
# RCSPartyCountry                              RCSPartyCountry                                String
# RCSPartyCountryLeaf                          RCSPartyCountryLeaf                            String
# RCSTRBC                                      RCSTRBC                                        String
# RCSTRBC2012                                  RCSTRBC2012                                    String
# RCSTRBC2012Genealogy                         RCSTRBC2012Genealogy                           String
# RCSTRBC2012Leaf                              RCSTRBC2012Leaf                                String
# RCSTRBC2012LeafML                            RCSTRBC2012LeafML                              String
# RCSTRBC2012Name                              RCSTRBC2012Name                                String
# RCSTRBC2012NameML                            RCSTRBC2012NameML                              String
# RCSTRBCGenealogy                             RCSTRBCGenealogy                               String
# RCSTRBCLeaf                                  RCSTRBCLeaf                                    String
# RCSTRBCLeafML                                RCSTRBCLeafML                                  String
# RCSTRBCName                                  RCSTRBCName                                    String
# RCSTRBCNameML                                RCSTRBCNameML                                  String
# ReasonDelisted                               ReasonDelisted                                 String
# REC                                          REC                                            String
# Red6Code                                     Red6Code                                       String
# RegistrationAuthorityName                    RegistrationAuthorityName                      String
# RegistrationAuthorityOrganizationID          RegistrationAuthorityOrganizationID            String
# RegistrationNumber                           RegistrationNumber                             String
# RegistrationNumberSearch                     RegistrationNumberSearch                       String
# ReutersIndustryClassification                ReutersIndustryClassification                  String
# Revenue                                      Revenue                                        Double
# RevenueGrowth5Y                              RevenueGrowth5Y                                Double
# RevenueGrowthInterim                         RevenueGrowthInterim                           Double
# RevenueInterim                               RevenueInterim                                 Double
# RevenueUsd                                   RevenueUsd                                     Double
# RIC                                          RIC                                            String
# Roe                                          Roe                                            Double
# Rofa                                         Rofa                                           Double
# Rota                                         Rota                                           Double
# SalesToAssets                                SalesToAssets                                  Double
# SalesToInventory                             SalesToInventory                               Double
# SalesToReceivables                           SalesToReceivables                             Double
# SalesToWorkingCap                            SalesToWorkingCap                              Double
# SDCCUSIP                                     SDCCUSIP                                       String
# SDCID                                        SDCID                                          String
# SearchAllCategory                            SearchAllCategory                              String
# SearchAllCategoryv2                          SearchAllCategoryv2                            String
# SearchAllCategoryv3                          SearchAllCategoryv3                            String
# SEditAudit                                   SEditAudit                                     String
# SEDOL                                        SEDOL                                          String
# ShareholdersEquity                           ShareholdersEquity                             Double
# ShareholdersEquityUsd                        ShareholdersEquityUsd                          Double
# ShortName                                    ShortName                                      String
# ShortNameJaHani                              ShortNameJaHani                                String
# ShortNameJaHira                              ShortNameJaHira                                String
# ShortNameJaKana                              ShortNameJaKana                                String
# ShortNameZhHans                              ShortNameZhHans                                String
# ShortNameZhHant                              ShortNameZhHant                                String
# ShortTermDebt                                ShortTermDebt                                  Double
# SiccScheme                                   SiccScheme                                     String
# SiccSchemeCode                               SiccSchemeCode                                 String
# SiccSchemeJa                                 SiccSchemeJa                                   String
# SicScheme                                    SicScheme                                      String
# SicSchemeCode                                SicSchemeCode                                  String
# SigDevExist                                  SigDevExist                                   Boolean
# SinotrustNumber                              SinotrustNumber                                String
# SolvencyMargin                               SolvencyMargin                                 Double
# Source                                       Source                                         String
# SPIssuerRating                               SPIssuerRating                                 String
# SponsorBondsExist                            SponsorBondsExist                             Boolean
# SpotCurrencyRIC                              SpotCurrencyRIC                                String
# SpotRIC                                      SpotRIC                                        String
# SPsRatingOutlookRank                         SPsRatingOutlookRank                           String
# SPsRatingPreliminary                         SPsRatingPreliminary                           String
# SPsRatingRank                                SPsRatingRank                                  String
# SPsRatingScopeRank                           SPsRatingScopeRank                             String
# SPsRatingsScope                              WatchCodeRank                                 Integer
#                                              Preliminary                                    String
#                                              Agency                                         String
#                                              CurrentRating                                  String
#                                              RatingType                                     String
#                                              Outlook                                        String
#                                              CurrentRatingDate                                Date
#                                              PreviousRatingDate                               Date
#                                              WatchCode                                      String
#                                              WatchEffectiveDate                               Date
#                                              CurrentRatingRank                             Integer
#                                              PreviousRating                                 String
#                                              Solicited                                      String
#                                              PreviousRatingRank                            Integer
#                                              OutlookRank                                   Integer
#                                              RatingScope                                    String
#                                              OutlookEffectiveDate                             Date
#                                              SPsRatingsScope                                Nested
# SPsRatingType                                SPsRatingType                                  String
# SPsRatingWatchCodeRank                       SPsRatingWatchCodeRank                         String
# StaffCosts                                   StaffCosts                                     Double
# SubjectBoost                                 SubjectBoost                                   String
# SubsidiariesBondsCount                       SubsidiariesBondsCount                         Double
# SubsidiariesCount                            SubsidiariesCount                              Double
# SucceededCompanyGEMPermID                    SucceededCompanyGEMPermID                      String
# SucceededCompanyNDAPI                        SucceededCompanyNDAPI                          String
# SucceededCompanyOAPermID                     SucceededCompanyOAPermID                       String
# SucceededCompanyPI                           SucceededCompanyPI                             String
# SucceededCompanyPrimaryRIC                   SucceededCompanyPrimaryRIC                     String
# SucceededOrganisationName                    SucceededOrganisationName                      String
# SucceededOrganisationOrgid                   SucceededOrganisationOrgid                     String
# TaxID                                        TaxID                                          String
# Ticker                                       Ticker                                         String
# TMTCompanyID                                 TMTCompanyID                                   String
# TotalAssets                                  TotalAssets                                    Double
# TotalAssetsToEquity                          TotalAssetsToEquity                            Double
# TotalAssetsUsd                               TotalAssetsUsd                                 Double
# ...
# RCSOrganisationSubTypeLeafML                 RCSOrganisationSubTypeLeafML                   False
# RCSOrganisationSubTypeName                   RCSOrganisationSubTypeName                     False
# RCSOrganisationSubTypeNameML                 RCSOrganisationSubTypeNameML                   False
# RCSOrganisationType                          RCSOrganisationType                            False
# RCSOrganisationTypeGenealogy                 RCSOrganisationTypeGenealogy                   False
# RCSOrganisationTypeLeaf                      RCSOrganisationTypeLeaf                        False
# RCSOrganisationTypeLeafML                    RCSOrganisationTypeLeafML                      False
# RCSOrganisationTypeName                      RCSOrganisationTypeName                        False
# RCSOrganisationTypeNameML                    RCSOrganisationTypeNameML                      False
# RCSOriginalAccountsCurrency                  RCSOriginalAccountsCurrency                    False
# RCSOriginalAccountsCurrencyGenealogy         RCSOriginalAccountsCurrencyGenealogy           False
# RCSOriginalAccountsCurrencyLeaf              RCSOriginalAccountsCurrencyLeaf                False
# RCSOriginalAccountsCurrencyLeafML            RCSOriginalAccountsCurrencyLeafML              False
# RCSOriginalAccountsCurrencyName              RCSOriginalAccountsCurrencyName                False
# RCSOriginalAccountsCurrencyNameML            RCSOriginalAccountsCurrencyNameML              False
# RCSPartyCountry                              RCSPartyCountry                                False
# RCSPartyCountryLeaf                          RCSPartyCountryLeaf                            False
# RCSTRBC                                      RCSTRBC                                        False
# RCSTRBC2012                                  RCSTRBC2012                                    False
# RCSTRBC2012Genealogy                         RCSTRBC2012Genealogy                           False
# RCSTRBC2012Leaf                              RCSTRBC2012Leaf                                False
# RCSTRBC2012LeafML                            RCSTRBC2012LeafML                              False
# RCSTRBC2012Name                              RCSTRBC2012Name                                False
# RCSTRBC2012NameML                            RCSTRBC2012NameML                              False
# RCSTRBCGenealogy                             RCSTRBCGenealogy                               False
# RCSTRBCLeaf                                  RCSTRBCLeaf                                    False
# RCSTRBCLeafML                                RCSTRBCLeafML                                  False
# RCSTRBCName                                  RCSTRBCName                                    False
# RCSTRBCNameML                                RCSTRBCNameML                                  False
# ReasonDelisted                               ReasonDelisted                                 False
# REC                                          REC                                            False
# Red6Code                                     Red6Code                                        True
# RegistrationAuthorityName                    RegistrationAuthorityName                      False
# RegistrationAuthorityOrganizationID          RegistrationAuthorityOrganizationID             True
# RegistrationNumber                           RegistrationNumber                              True
# RegistrationNumberSearch                     RegistrationNumberSearch                       False
# ReutersIndustryClassification                ReutersIndustryClassification                  False
# Revenue                                      Revenue                                        False
# RevenueGrowth5Y                              RevenueGrowth5Y                                False
# RevenueGrowthInterim                         RevenueGrowthInterim                           False
# RevenueInterim                               RevenueInterim                                 False
# RevenueUsd                                   RevenueUsd                                     False
# RIC                                          RIC                                             True
# Roe                                          Roe                                            False
# Rofa                                         Rofa                                           False
# Rota                                         Rota                                           False
# SalesToAssets                                SalesToAssets                                  False
# SalesToInventory                             SalesToInventory                               False
# SalesToReceivables                           SalesToReceivables                             False
# SalesToWorkingCap                            SalesToWorkingCap                              False
# SDCCUSIP                                     SDCCUSIP                                        True
# SDCID                                        SDCID                                           True
# SearchAllCategory                            SearchAllCategory                              False
# SearchAllCategoryv2                          SearchAllCategoryv2                            False
# SearchAllCategoryv3                          SearchAllCategoryv3                            False
# SEditAudit                                   SEditAudit                                     False
# SEDOL                                        SEDOL                                           True
# ShareholdersEquity                           ShareholdersEquity                             False
# ShareholdersEquityUsd                        ShareholdersEquityUsd                          False
# ShortName                                    ShortName                                      False
# ShortNameJaHani                              ShortNameJaHani                                False
# ShortNameJaHira                              ShortNameJaHira                                False
# ShortNameJaKana                              ShortNameJaKana                                False
# ShortNameZhHans                              ShortNameZhHans                                False
# ShortNameZhHant                              ShortNameZhHant                                False
# ShortTermDebt                                ShortTermDebt                                  False
# SiccScheme                                   SiccScheme                                     False
# SiccSchemeCode                               SiccSchemeCode                                  True
# SiccSchemeJa                                 SiccSchemeJa                                   False
# SicScheme                                    SicScheme                                      False
# SicSchemeCode                                SicSchemeCode                                   True
# SigDevExist                                  SigDevExist                                    False
# SinotrustNumber                              SinotrustNumber                                 True
# SolvencyMargin                               SolvencyMargin                                 False
# Source                                       Source                                         False
# SPIssuerRating                               SPIssuerRating                                 False
# SponsorBondsExist                            SponsorBondsExist                              False
# SpotCurrencyRIC                              SpotCurrencyRIC                                False
# SpotRIC                                      SpotRIC                                        False
# SPsRatingOutlookRank                         SPsRatingOutlookRank                            True
# SPsRatingPreliminary                         SPsRatingPreliminary                           False
# SPsRatingRank                                SPsRatingRank                                   True
# SPsRatingScopeRank                           SPsRatingScopeRank                             False
# SPsRatingsScope                              WatchCodeRank                                  False
#                                              Preliminary                                    False
#                                              Agency                                         False
#                                              CurrentRating                                  False
#                                              RatingType                                     False
#                                              Outlook                                        False
#                                              CurrentRatingDate                              False
#                                              PreviousRatingDate                             False
#                                              WatchCode                                      False
#                                              WatchEffectiveDate                             False
#                                              CurrentRatingRank                              False
#                                              PreviousRating                                 False
#                                              Solicited                                      False
#                                              PreviousRatingRank                             False
#                                              OutlookRank                                    False
#                                              RatingScope                                    False
#                                              OutlookEffectiveDate                           False
#                                              SPsRatingsScope                                False
# SPsRatingType                                SPsRatingType                                  False
# SPsRatingWatchCodeRank                       SPsRatingWatchCodeRank                          True
# StaffCosts                                   StaffCosts                                     False
# SubjectBoost                                 SubjectBoost                                    True
# SubsidiariesBondsCount                       SubsidiariesBondsCount                         False
# SubsidiariesCount                            SubsidiariesCount                              False
# SucceededCompanyGEMPermID                    SucceededCompanyGEMPermID                       True
# SucceededCompanyNDAPI                        SucceededCompanyNDAPI                          False
# SucceededCompanyOAPermID                     SucceededCompanyOAPermID                        True
# SucceededCompanyPI                           SucceededCompanyPI                             False
# SucceededCompanyPrimaryRIC                   SucceededCompanyPrimaryRIC                      True
# SucceededOrganisationName                    SucceededOrganisationName                      False
# SucceededOrganisationOrgid                   SucceededOrganisationOrgid                     False
# TaxID                                        TaxID                                           True
# Ticker                                       Ticker                                          True
# TMTCompanyID                                 TMTCompanyID                                    True
# TotalAssets                                  TotalAssets                                    False
# TotalAssetsToEquity                          TotalAssetsToEquity                            False
# TotalAssetsUsd                               TotalAssetsUsd                                 False
# TotalCapitalRatio                            TotalCapitalRatio                              False
# TotalLiabilities                             TotalLiabilities                               False
# TotalLiabilitiesUsd                          TotalLiabilitiesUsd                            False
# TotalOperatingIncome                         TotalOperatingIncome                           False
# TotalScore                                   TotalScore                                     False
# TRBC2012PrimaryCode                          TRBC2012PrimaryCode                             True
# TRBC2012PrimaryCodeMeaning                   TRBC2012PrimaryCodeMeaning                     False
# TRBCHierarchicalCode                         TRBCHierarchicalCode                            True
# TRBCHierarchicalCodeMeaning                  TRBCHierarchicalCodeMeaning                    False
# TRBCHierarchicalShortCode                    TRBCHierarchicalShortCode                       True
# TRBCPrimaryCode                              TRBCPrimaryCode                                 True
# TRBCPrimaryCodeMeaning                       TRBCPrimaryCodeMeaning                         False
# TRBCPrimaryIndustryID                        TRBCPrimaryIndustryID                           True
# UltimateParentCompanyGEMPermID               UltimateParentCompanyGEMPermID                  True
# UltimateParentCompanyNDAPI                   UltimateParentCompanyNDAPI                     False
# UltimateParentCompanyOAPermID                UltimateParentCompanyOAPermID                   True
# UltimateParentCompanyPI                      UltimateParentCompanyPI                        False
# UltimateParentIssuerEquityPrimaryRIC         UltimateParentIssuerEquityPrimaryRIC           False
# UltimateParentOrganisationName               UltimateParentOrganisationName                 False
# UltimateParentOrganisationNameJaHani         UltimateParentOrganisationNameJaHani           False
# UltimateParentOrganisationOrgid              UltimateParentOrganisationOrgid                False
# UltimateParentOrganizationID                 UltimateParentOrganizationID                   False
# UltimateSucceededCompanyGEMPermID            UltimateSucceededCompanyGEMPermID               True
# UltimateSucceededCompanyNDAPI                UltimateSucceededCompanyNDAPI                  False
# UltimateSucceededCompanyOAPermID             UltimateSucceededCompanyOAPermID                True
# UltimateSucceededCompanyPI                   UltimateSucceededCompanyPI                     False
# UltimateSucceededOrganisationName            UltimateSucceededOrganisationName              False
# UltimateSucceededOrganisationOrgid           UltimateSucceededOrganisationOrgid             False
# UnderlyingEquityOptionIssueCount             UnderlyingEquityOptionIssueCount               False
# UnderlyingEquityQuoteIssueCount              UnderlyingEquityQuoteIssueCount                False
# UnderwritingRatio                            UnderwritingRatio                              False
# ValuationQuotePI                             ValuationQuotePI                                True
# VEFirmID                                     VEFirmID                                        True
# VentureEconomicsID                           VentureEconomicsID                              True
# WarrantsCount                                WarrantsCount                                  False
# WebsiteName                                  WebsiteName                                    False
# WorldscopeCompanyID                          WorldscopeCompanyID                             True
# WorldscopeCompanyPermID                      WorldscopeCompanyPermID                         True
# YearHighToday2RIC                            YearHighToday2RIC                              False
# YearLowToday2RIC                             YearLowToday2RIC                               False

# %% [markdown]
# ## Gather information for all companies which have a Parent Company
# The fact that these companies exist in the companies dataset means that their financials are reported seeperately. These companies also have a strong chance of having been acquired at some point since they have a parent company.

# %%
# Need to execute a seperate search on each industry to avoid API Limits on the number of search results
GicsNames = ['Industrials', 'Consumer Staples', 'Materials', 'Health Care', 'Informational Technology', 'Financials', 'Real Estate', 'Consumer Discretionary', 'Energy', 'Communication Services', 'Utilities']

subsidiaries = [] # Stores the dfs for each industry

# Iterate through each industry and find all companies which have a parent company
for name in GicsNames:

    sub_df = ld.discovery.search(
        view=ld.discovery.Views.ORGANISATIONS,
        select="CommonName, UltimateParentOrganisationName", 
        filter=f"UltimateParentOrganisationName ne null and GicsName eq '{name}'",
        top=10000
    )
    subsidiaries.append(sub_df)

subsidiary_df = pd.concat(subsidiaries, ignore_index=True)
print(len(subsidiary_df))
subsidiary_df.head()
# Out:
# 47106
#                            CommonName      UltimateParentOrganisationName
# 0  International Holding Company PJSC  International Holding Company PJSC
# 1                 General Electric Co                 General Electric Co
# 2                     Caterpillar Inc                     Caterpillar Inc
# 3                            RTX Corp                            RTX Corp
# 4                          Siemens AG                          Siemens AG

# %% [markdown]
# ## As one can see, often the organisation itself is listed as its own ultimate parent. For this reason, we filter the df to exclude all cases in which the parent and company name are the same.

# %%
# Filter rows where CommonName is not the same as UltimateParentOrganisationName
subsidiary_df = subsidiary_df[(subsidiary_df['CommonName'] != subsidiary_df['UltimateParentOrganisationName'])]

subsidiary_df.head()
# Out:
#                                     CommonName  \
# 6       Contemporary Amperex Technology Co Ltd
# 31                        Thomson Reuters Corp
# 36                      LG Energy Solution Ltd
# 75                                      WEG SA
# 77  Beijing-Shanghai High Speed Railway Co Ltd
#
#               UltimateParentOrganisationName
# 6           Xiamen Ruiting Investment Co Ltd
# 31                    Woodbridge Company Ltd
# 36                               LG Chem Ltd
# 75           WPA Participacoes e Servicos SA
# 77  China, People's Republic of (Government)

# %%
# Get M&A deals metadata
# To get organization metadata
ld.open_session()

response = search.metadata.Definition(
    view = search.Views.DEALS_MERGERS_AND_ACQUISITIONS  # Required parameterc
).get_data()


# Set display options to print the entire DataFrame
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_colwidth', None)  # Show full content in each cell

# Now, print the entire DataFrame
print(response.data.df)

# Reset display options if you don't want this setting to persist
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.max_colwidth')
# Out:
#                                               Type  Searchable  Sortable  \
# AcquirerAdvisorCode                         String        True     False
# AcquirerAdvisorCountry                      String        True     False
# AcquirerAdvisorCusip                        String        True     False
# AcquirerAdvisorName                         String        True     False
# AcquirerAdvisorOAPermId                     String        True     False
# AcquirerAdvisorRegion                       String        True     False
# AcquirerAdvisorRegionCode                   String        True     False
# AcquirerAdvisorRole                         String        True     False
# AcquirerAdvisorSubRegion                    String        True     False
# AcquirerAdvisorSubRegionCode                String        True     False
# AcquirerAdvisorSubRole                      String        True     False
# AcquirerBusinessDescriptionLong             String        True     False
# AcquirerBusinessDescriptionShort            String        True     False
# AcquirerCidgen                              String        True     False
# AcquirerCompanyAliasName                    String        True     False
# AcquirerCompanyAlternativeName              String        True     False
# AcquirerCompanyName                         String        True      True
# AcquirerCountry                             String        True      True
# AcquirerCusip                               String        True     False
# AcquirerEANCommonName                       String        True     False
# AcquirerImmediateParentCidgen               String        True     False
# AcquirerImmediateParentName                 String        True     False
# AcquirerImmediateParentOAPermID             String        True     False
# AcquirerMidIndustry                         String        True      True
# AcquirerMidIndustryCode                     String        True     False
# AcquirerNAICS                               String        True     False
# AcquirerNAICSCode                           String        True     False
# AcquirerName                                String        True     False
# AcquirerOAPermId                            String        True     False
# AcquirerPublicStatus                        String        True      True
# AcquirerPublicStatusCode                    String        True     False
# AcquirerRegion                              String        True      True
# AcquirerRegionCode                          String        True      True
# AcquirerRIC                                 String        True     False
# AcquirerSDC                                 String        True     False
# AcquirerSDCCode                             String        True     False
# AcquirerShortName                           String        True     False
# AcquirerStockPriceOnAnnouncementDay         String        True     False
# AcquirerStockPriceOneDayAfterAnnouncement   String        True     False
# AcquirerSubRegion                           String        True      True
# AcquirerSubRegionCode                       String        True     False
# AcquirerTRBCCode                            String        True     False
# AcquirerUltimateParentCidgen                String        True     False
# AcquirerUltimateParentName                  String        True      True
# AcquirerUltimateParentOAPermID              String        True     False
# AcquirerUSStateCode                         String        True     False
# AnalystEstimatedValue                       Double        True      True
# Attitude                                    String        True      True
# AttitudeCode                                String        True     False
# BusinessEntity                              String        True      True
# ConsiderationOffered                        String        True     False
# ConsiderationOfferedCode                    String        True     False
# ConsiderationSought                         String        True     False
# ConsiderationSoughtCode                     String        True     False
# ConsiderationText                           String        True     False
# CurrencyCodeOfTransaction                   String        True      True
# DateDealWasLastUpdated                        Date        True      True
# DealPurpose                                 String        True     False
# DealPurposeCode                             String        True     False
# DocumentTitle                               String        True      True
# DTCharacteristics                           String       False     False
# DTSimpleType                                String        True      True
# DTSource                                    String        True      True
# DTSubjectName                               String        True      True
# FairnessOpinionAuthor                       String        True     False
# FairnessOpinionAuthorCode                   String        True     False
# FairnessOpinionDate                           Date        True      True
# FormOfTransactionCode                       String        True      True
# FormOfTransactionName                       String        True      True
# GEMQuotationID                              String        True     False
# HKAlias                                     String        True     False
# HKVersion                                   String        True     False
# InitialPricePerShare                        Double        True      True
# InsertDateTime                                Date        True      True
# InvestorCidgen                              String        True     False
# InvestorCompanyName                         String        True      True
# InvestorCountry                             String        True     False
# InvestorCusip                               String        True     False
# InvestorEANCommonName                       String        True     False
# InvestorOAPermId                            String        True     False
# InvestorPublicStatus                        String        True     False
# InvestorPublicStatusCode                    String        True     False
# InvestorRegion                              String        True     False
# InvestorRegionCode                          String        True     False
# InvestorRIC                                 String        True     False
# InvestorSubRegion                           String        True     False
# InvestorSubRegionCode                       String        True     False
# IsFlashDeal                                Boolean        True      True
# Keywords                                    String        True      True
# ParticipantNames                            String        True     False
# ParticipantOAPermIds                        String        True     False
# ParticipantRCSCountryNames                  String        True     False
# ParticipantRICs                             String        True     False
# ParticipantTRBCCodes                        String        True     False
# ParticipantTRBCLeafs                        String        True     False
# PercentageOfSharesAcquired                  Double        True      True
# PermID                                      String        True     False
# PI                                          String        True     False
# PremiumAsOn1DayPriorToAnnouncementDate      Double        True      True
# PremiumAsOn1WeekPriorToAnnouncementDate     Double        True      True
# PremiumAsOn4WeeksPriorToAnnouncementDate    Double        True      True
# PricePerShare                               Double        True      True
# Purpose                                     String        True      True
# RankDate                                      Date        True      True
# RatioOfRankvalueToCashFlow                  Double        True      True
# RatioOfRankvalueToEBIT                      Double        True      True
# RatioOfRankvalueToNetAssets                 Double        True      True
# RatioOfRankvalueToNetIncome                 Double        True      True
# RatioOfRankvalueToSales                     Double        True      True
# RatioOfTransactionValueToCashFlow           Double        True      True
# RatioOfTransactionValueToEBIT               Double        True      True
# RatioOfTransactionValueToNetAssets          Double        True      True
# RatioOfTransactionValueToNetIncome          Double        True      True
# RatioOfTransactionValueToSales              Double        True      True
# RCSAcquirerCountry                          String        True     False
# RCSAcquirerCountryGenealogy                 String        True     False
# RCSAcquirerCountryGenealogyName             String        True     False
# RCSAcquirerCountryName                      String        True      True
# RCSAcquirerTRBC                             String        True     False
# RCSAcquirerTRBCGenealogy                    String        True     False
# RCSAcquirerTRBCLeaf                         String        True      True
# RCSAcquirerTRBCName                         String        True      True
# RCSAcquirerUSState                          String        True     False
# RCSAcquirerUSStateLeaf                      String        True     False
# RCSCurrencyGenealogyName                    String        True     False
# RCSCurrencyName                             String        True     False
# RCSInvestorCountry                          String        True     False
# RCSInvestorCountryGenealogy                 String        True     False
# RCSInvestorCountryGenealogyName             String        True     False
# RCSInvestorCountryName                      String        True     False
# RCSSellerCountry                            String        True     False
# RCSSellerCountryGenealogy                   String        True     False
# RCSSellerCountryGenealogyName               String        True     False
# RCSSellerCountryName                        String        True     False
# RCSTargetCountry                            String        True     False
# RCSTargetCountryGenealogy                   String        True     False
# RCSTargetCountryGenealogyName               String        True     False
# RCSTargetCountryName                        String        True      True
# RCSTargetTRBC                               String        True     False
# RCSTargetTRBCGenealogy                      String        True     False
# RCSTargetTRBCLeaf                           String        True      True
# RCSTargetTRBCName                           String        True      True
# RCSTargetUSState                            String        True     False
# RCSTargetUSStateLeaf                        String        True     False
# SdcDealNumber                               String        True      True
# SearchAllCategory                           String        True      True
# SearchAllCategoryv2                         String        True      True
# SearchAllCategoryv3                         String        True      True
# SellerCidgen                                String        True     False
# SellerCompanyName                           String        True      True
# SellerCountry                               String        True     False
# SellerCusip                                 String        True     False
# SellerEANCommonName                         String        True     False
# SellerOAPermId                              String        True     False
# SellerPublicStatus                          String        True     False
# SellerPublicStatusCode                      String        True     False
# SellerRegion                                String        True     False
# SellerRegionCode                            String        True     False
# SellerRIC                                   String        True     False
# SellerSubRegion                             String        True     False
# SellerSubRegionCode                         String        True     False
# Source                                      String        True     False
# SubjectBoost                                String        True     False
# TargetAdvisorCode                           String        True     False
# TargetAdvisorCountry                        String        True     False
# TargetAdvisorCusip                          String        True     False
# TargetAdvisorName                           String        True     False
# TargetAdvisorOAPermId                       String        True     False
# TargetAdvisorRegion                         String        True     False
# TargetAdvisorRegionCode                     String        True     False
# TargetAdvisorRole                           String        True      True
# TargetAdvisorSubRegion                      String        True     False
# TargetAdvisorSubRegionCode                  String        True     False
# TargetAdvisorSubRole                        String        True     False
# TargetBusinessDescriptionLong               String        True     False
# TargetBusinessDescriptionShort              String        True     False
# TargetCidgen                                String        True     False
# TargetCompanyAliasName                      String        True     False
# TargetCompanyAlternativeName                String        True     False
# TargetCompanyName                           String        True      True
# TargetCountry                               String        True      True
# TargetCusip                                 String        True     False
# TargetEANCommonName                         String        True     False
# TargetImmediateParentCidgen                 String        True     False
# TargetImmediateParentName                   String        True     False
# TargetImmediateParentOAPermID               String        True     False
# TargetMidIndustry                           String        True      True
# TargetMidIndustryCode                       String        True     False
# TargetNAICS                                 String        True     False
# TargetNAICSCode                             String        True     False
# TargetName                                  String        True     False
# TargetOAPermId                              String        True     False
# TargetPublicStatus                          String        True      True
# TargetPublicStatusCode                      String        True     False
# TargetRegion                                String        True      True
# TargetRegionCode                            String        True     False
# TargetRIC                                   String        True     False
# TargetSDC                                   String        True     False
# TargetSDCCode                               String        True     False
# TargetShortName                             String        True     False
# TargetStockPriceOnAnnouncementDay           String        True     False
# TargetStockPriceOneDayAfterAnnouncement     String        True     False
# TargetSubRegion                             String        True      True
# TargetSubRegionCode                         String        True      True
# TargetTRBC                                  String        True      True
# TargetTRBCCode                              String        True     False
# TargetUltimateParentCidgen                  String        True     False
# TargetUltimateParentName                    String        True      True
# TargetUltimateParentOAPermID                String        True     False
# TargetUSStateCode                           String        True     False
# TransactionAnnouncementDate                   Date        True      True
# TransactionComparableDealNumber             String        True     False
# TransactionEffectiveDate                      Date        True      True
# TransactionStatus                           String        True      True
# TransactionStatusCode                       String        True     False
# TransactionSynopsis                         String        True     False
# TransactionValueIncludingNetDebtOfTarget    Double        True      True
#
#                                            Navigable  Groupable  Exact  Symbol
# AcquirerAdvisorCode                            False       True  False    True
# AcquirerAdvisorCountry                         False      False  False   False
# AcquirerAdvisorCusip                           False      False  False   False
# AcquirerAdvisorName                             True      False   True   False
# AcquirerAdvisorOAPermId                        False      False  False   False
# AcquirerAdvisorRegion                          False      False  False   False
# AcquirerAdvisorRegionCode                      False       True  False    True
# AcquirerAdvisorRole                            False      False  False   False
# AcquirerAdvisorSubRegion                       False      False  False   False
# AcquirerAdvisorSubRegionCode                   False       True  False    True
# AcquirerAdvisorSubRole                         False      False  False   False
# AcquirerBusinessDescriptionLong                False      False  False   False
# AcquirerBusinessDescriptionShort               False      False  False   False
# AcquirerCidgen                                 False      False  False   False
# AcquirerCompanyAliasName                       False      False  False   False
# AcquirerCompanyAlternativeName                 False      False  False   False
# AcquirerCompanyName                            False      False  False   False
# AcquirerCountry                                False      False  False   False
# AcquirerCusip                                  False      False  False   False
# AcquirerEANCommonName                          False      False  False   False
# AcquirerImmediateParentCidgen                  False      False  False   False
# AcquirerImmediateParentName                    False      False  False   False
# AcquirerImmediateParentOAPermID                False      False  False   False
# AcquirerMidIndustry                             True       True   True   False
# AcquirerMidIndustryCode                        False       True  False    True
# AcquirerNAICS                                  False      False  False   False
# AcquirerNAICSCode                              False       True  False    True
# AcquirerName                                   False      False  False   False
# AcquirerOAPermId                               False      False  False   False
# AcquirerPublicStatus                            True       True   True   False
# AcquirerPublicStatusCode                       False       True  False    True
# AcquirerRegion                                  True       True   True   False
# AcquirerRegionCode                             False       True  False    True
# AcquirerRIC                                    False       True  False    True
# AcquirerSDC                                    False      False  False   False
# AcquirerSDCCode                                False       True  False    True
# AcquirerShortName                              False      False  False   False
# AcquirerStockPriceOnAnnouncementDay            False      False  False   False
# AcquirerStockPriceOneDayAfterAnnouncement      False      False  False   False
# AcquirerSubRegion                               True       True   True   False
# AcquirerSubRegionCode                          False       True  False    True
# AcquirerTRBCCode                               False       True  False    True
# AcquirerUltimateParentCidgen                   False      False  False   False
# AcquirerUltimateParentName                     False      False  False   False
# AcquirerUltimateParentOAPermID                 False      False  False   False
# AcquirerUSStateCode                             True       True   True    True
# AnalystEstimatedValue                           True      False  False   False
# Attitude                                        True       True   True   False
# AttitudeCode                                   False       True  False    True
# BusinessEntity                                  True       True   True   False
# ConsiderationOffered                           False      False  False   False
# ConsiderationOfferedCode                       False       True  False    True
# ConsiderationSought                            False      False  False   False
# ConsiderationSoughtCode                        False       True  False    True
# ConsiderationText                              False      False  False   False
# CurrencyCodeOfTransaction                      False      False  False   False
# DateDealWasLastUpdated                          True      False  False   False
# DealPurpose                                     True      False   True   False
# DealPurposeCode                                False       True  False    True
# DocumentTitle                                  False      False  False   False
# DTCharacteristics                              False      False  False   False
# DTSimpleType                                    True       True   True   False
# DTSource                                       False      False  False   False
# DTSubjectName                                  False      False  False   False
# FairnessOpinionAuthor                          False      False  False   False
# FairnessOpinionAuthorCode                      False       True  False    True
# FairnessOpinionDate                             True      False  False   False
# FormOfTransactionCode                          False       True  False    True
# FormOfTransactionName                           True       True   True   False
# GEMQuotationID                                 False       True   True    True
# HKAlias                                         True       True   True   False
# HKVersion                                      False      False  False   False
# InitialPricePerShare                            True      False  False   False
# InsertDateTime                                  True      False  False   False
# InvestorCidgen                                 False      False  False   False
# InvestorCompanyName                            False      False  False   False
# InvestorCountry                                False      False  False   False
# InvestorCusip                                  False      False  False   False
# InvestorEANCommonName                          False      False  False   False
# InvestorOAPermId                               False      False  False   False
# InvestorPublicStatus                           False      False  False   False
# InvestorPublicStatusCode                       False       True  False    True
# InvestorRegion                                 False      False  False   False
# InvestorRegionCode                             False       True  False    True
# InvestorRIC                                    False       True  False    True
# InvestorSubRegion                              False      False  False   False
# InvestorSubRegionCode                          False       True  False    True
# IsFlashDeal                                    False      False  False   False
# Keywords                                        True       True   True   False
# ParticipantNames                               False      False  False   False
# ParticipantOAPermIds                           False      False  False   False
# ParticipantRCSCountryNames                     False      False  False   False
# ParticipantRICs                                False      False  False   False
# ParticipantTRBCCodes                           False      False  False   False
# ParticipantTRBCLeafs                           False      False  False   False
# PercentageOfSharesAcquired                      True      False  False   False
# PermID                                         False       True   True    True
# PI                                             False       True  False    True
# PremiumAsOn1DayPriorToAnnouncementDate          True      False  False   False
# PremiumAsOn1WeekPriorToAnnouncementDate         True      False  False   False
# PremiumAsOn4WeeksPriorToAnnouncementDate        True      False  False   False
# PricePerShare                                   True      False  False   False
# Purpose                                         True       True   True   False
# RankDate                                        True      False  False   False
# RatioOfRankvalueToCashFlow                      True      False  False   False
# RatioOfRankvalueToEBIT                          True      False  False   False
# RatioOfRankvalueToNetAssets                     True      False  False   False
# RatioOfRankvalueToNetIncome                     True      False  False   False
# RatioOfRankvalueToSales                         True      False  False   False
# RatioOfTransactionValueToCashFlow               True      False  False   False
# RatioOfTransactionValueToEBIT                   True      False  False   False
# RatioOfTransactionValueToNetAssets              True      False  False   False
# RatioOfTransactionValueToNetIncome              True      False  False   False
# RatioOfTransactionValueToSales                  True      False  False   False
# RCSAcquirerCountry                             False      False  False   False
# RCSAcquirerCountryGenealogy                    False      False  False   False
# RCSAcquirerCountryGenealogyName                False      False  False   False
# RCSAcquirerCountryName                          True       True   True   False
# RCSAcquirerTRBC                                False      False  False   False
# RCSAcquirerTRBCGenealogy                        True       True   True   False
# RCSAcquirerTRBCLeaf                             True       True   True   False
# RCSAcquirerTRBCName                             True       True   True   False
# RCSAcquirerUSState                             False      False  False   False
# RCSAcquirerUSStateLeaf                          True      False   True   False
# RCSCurrencyGenealogyName                       False      False  False   False
# RCSCurrencyName                                False      False  False   False
# RCSInvestorCountry                             False      False  False   False
# RCSInvestorCountryGenealogy                    False      False  False   False
# RCSInvestorCountryGenealogyName                False      False  False   False
# RCSInvestorCountryName                         False      False  False   False
# RCSSellerCountry                               False      False  False   False
# RCSSellerCountryGenealogy                      False      False  False   False
# RCSSellerCountryGenealogyName                  False      False  False   False
# RCSSellerCountryName                           False      False  False   False
# RCSTargetCountry                               False      False  False   False
# RCSTargetCountryGenealogy                      False      False  False   False
# RCSTargetCountryGenealogyName                  False      False  False   False
# RCSTargetCountryName                            True       True   True   False
# RCSTargetTRBC                                  False      False  False   False
# RCSTargetTRBCGenealogy                          True       True   True   False
# RCSTargetTRBCLeaf                               True       True   True   False
# RCSTargetTRBCName                               True       True   True   False
# RCSTargetUSState                               False      False  False   False
# RCSTargetUSStateLeaf                            True      False   True   False
# SdcDealNumber                                  False      False  False   False
# SearchAllCategory                               True       True   True   False
# SearchAllCategoryv2                             True       True   True   False
# SearchAllCategoryv3                             True       True   True   False
# SellerCidgen                                   False      False  False   False
# SellerCompanyName                              False      False  False   False
# SellerCountry                                  False      False  False   False
# SellerCusip                                    False      False  False   False
# SellerEANCommonName                            False      False  False   False
# SellerOAPermId                                 False      False  False   False
# SellerPublicStatus                             False      False  False   False
# SellerPublicStatusCode                         False       True  False    True
# SellerRegion                                   False      False  False   False
# SellerRegionCode                               False       True  False    True
# SellerRIC                                      False       True  False    True
# SellerSubRegion                                False      False  False   False
# SellerSubRegionCode                            False       True  False    True
# Source                                         False      False  False   False
# SubjectBoost                                   False       True  False    True
# TargetAdvisorCode                              False       True  False    True
# TargetAdvisorCountry                           False      False  False   False
# TargetAdvisorCusip                             False      False  False   False
# TargetAdvisorName                               True      False   True   False
# TargetAdvisorOAPermId                          False      False  False   False
# TargetAdvisorRegion                            False      False  False   False
# TargetAdvisorRegionCode                        False       True  False    True
# TargetAdvisorRole                               True       True   True   False
# TargetAdvisorSubRegion                         False      False  False   False
# TargetAdvisorSubRegionCode                     False       True  False    True
# TargetAdvisorSubRole                           False      False  False   False
# TargetBusinessDescriptionLong                  False      False  False   False
# TargetBusinessDescriptionShort                 False      False  False   False
# TargetCidgen                                   False      False  False   False
# TargetCompanyAliasName                         False      False  False   False
# TargetCompanyAlternativeName                   False      False  False   False
# TargetCompanyName                              False      False  False   False
# TargetCountry                                   True       True   True   False
# TargetCusip                                    False      False  False   False
# TargetEANCommonName                            False      False  False   False
# TargetImmediateParentCidgen                    False      False  False   False
# TargetImmediateParentName                      False      False  False   False
# TargetImmediateParentOAPermID                  False      False  False   False
# TargetMidIndustry                               True       True   True   False
# TargetMidIndustryCode                          False       True  False    True
# TargetNAICS                                    False      False  False   False
# TargetNAICSCode                                False       True  False    True
# TargetName                                     False      False  False   False
# TargetOAPermId                                 False      False  False   False
# TargetPublicStatus                              True       True   True   False
# TargetPublicStatusCode                         False       True  False    True
# TargetRegion                                    True       True   True   False
# TargetRegionCode                               False       True  False    True
# TargetRIC                                      False       True  False    True
# TargetSDC                                      False      False  False   False
# TargetSDCCode                                  False       True  False    True
# TargetShortName                                False      False  False   False
# TargetStockPriceOnAnnouncementDay              False      False  False   False
# TargetStockPriceOneDayAfterAnnouncement        False      False  False   False
# TargetSubRegion                                 True       True   True   False
# TargetSubRegionCode                            False       True  False    True
# TargetTRBC                                     False      False  False   False
# TargetTRBCCode                                 False       True  False    True
# TargetUltimateParentCidgen                     False      False  False   False
# TargetUltimateParentName                       False      False  False   False
# TargetUltimateParentOAPermID                   False      False  False   False
# TargetUSStateCode                               True       True   True    True
# TransactionAnnouncementDate                     True      False  False   False
# TransactionComparableDealNumber                False      False  False   False
# TransactionEffectiveDate                        True      False  False   False
# TransactionStatus                               True       True   True   False
# TransactionStatusCode                          False       True  False    True
# TransactionSynopsis                            False      False  False   False
# TransactionValueIncludingNetDebtOfTarget        True      False  False   False

# %% [markdown]
# ## Run a search to see if there exists an acquisiiton in the LSEG database where the company names are the same as the parent and subsidiary names from the company search. The goal here is to only find subsidiaries formed through acqusiition as opposed to spin offs or other deals

# %%
'''
Remove Additional Qualifiers to Company Names like Inc/LLC
These are often inconsistent pre and post acquisition and the LSEG search finds all matches up to the input
However, we still would like to have a mapping to go back to these names after we execute the search 
'''
def remove_qualifiers_and_create_mapping(df):
    # regex for all of the qualifier suffixes we want to remove
    suffixes = r"( LLC| PLC| Corp| Inc| Co| Ltd)$"
    
    # Create a mapping dictionary
    mapping = {}

    # Apply the cleaning function and populate the mapping dictionary
    for index, row in df.iterrows():

        cleaned_name = re.sub(suffixes, "", row['CommonName'], flags=re.IGNORECASE).strip()
        original_name = row['CommonName']

        # Only add to mapping if not already there
        if cleaned_name not in mapping:
            mapping[cleaned_name] = original_name
        
        # Clean the name in the DataFrame
        df.at[index, 'CommonName'] = cleaned_name

        # Do the same for the UltimateParentOrganisationName
        cleaned_parent_name = re.sub(suffixes, "", row['UltimateParentOrganisationName'], flags=re.IGNORECASE).strip()
        original_parent_name = row['UltimateParentOrganisationName']

        if cleaned_parent_name not in mapping:
            mapping[cleaned_parent_name] = original_parent_name
        
        df.at[index, 'UltimateParentOrganisationName'] = cleaned_parent_name

    return df, mapping

'''
Create a filter which restricts on when the AcquirerName in the M&A Deals datset equals the UltimateParentOrganisationName and the TargetName equals the CommonName
We create a list of 10 filters at a time to avoid the API restriction on the size of the filter
'''
def create_name_filter(df, batch_size):
    filters = []
    
    # Pre-process the names for filtering
    df['CleanedUltimateParent'] = df['UltimateParentOrganisationName'].str.replace("'", "''")
    df['CleanedCommonName'] = df['CommonName'].str.replace("'", "''")

    # Create filters in batches of 10
    for i in range(0, len(df), batch_size):
        batch = df.iloc[i:i + batch_size]
        batch_filter = " or ".join(
            f"(AcquirerName eq '{row['CleanedUltimateParent']}' and TargetName eq '{row['CleanedCommonName']}')"
            for _, row in batch.iterrows()
        )
        filters.append(batch_filter)
        
    return filters


subsidiary_df, name_mapping = remove_qualifiers_and_create_mapping(subsidiary_df)
filter_batches = create_name_filter(subsidiary_df,20)

# List to collect results from all the API calls on sets of 10 name filter pairs
deals = []

to_select = [
    "AcquirerName",
    "TargetName",
    "TransactionEffectiveDate",
    "PercentageOfSharesAcquired",
    "AcquirerRegion",
    "TargetRegion",
    "PricePerShare",
    "CurrencyCodeOfTransaction",
    "DealPurpose",
    "FormOfTransactionName",
    "TransactionStatus",
    "InitialPricePerShare",
    "PremiumAsOn1DayPriorToAnnouncementDate",
    "PremiumAsOn1WeekPriorToAnnouncementDate",
    "PremiumAsOn4WeeksPriorToAnnouncementDate",
    "AcquirerPublicStatus",
    "TargetPublicStatus",
    "AcquirerMidIndustry",
    "TargetMidIndustry",
    "AnalystEstimatedValue",
    "RatioOfTransactionValueToNetIncome",
    "RatioOfTransactionValueToCashFlow",
    "RatioOfTransactionValueToSales",
    "RatioOfRankvalueToNetIncome",
    "RatioOfRankvalueToCashFlow",
    "RatioOfRankvalueToSales",
    "TransactionValueIncludingNetDebtOfTarget"
]

select_string = ", ".join(to_select)

# Execute the search in batches and collect the results
for filter_string in filter_batches:
    deals_df = ld.discovery.search(
        view=search.Views.DEALS_MERGERS_AND_ACQUISITIONS,
        select=select_string,
        filter=filter_string
    )
    deals.append(deals_df)

# Combine all the individual DataFrames into one
combined_deals_df = pd.concat(deals, ignore_index=True)

# %%
# Set the maximum number of rows to display
pd.set_option('display.max_rows', None)  # Use None to display all rows

# Now print the TransactionStatus column
print(combined_deals_df['TransactionStatus'])
# Out:
# 0              Completed
# 1              Completed
# 2              Completed
# 3              Completed
# 4                Pending
# 5              Completed
# 6              Completed
# 7              Completed
# 8                Pending
# 9                Pending
# 10             Completed
# 11               Pending
# 12             Completed
# 13             Completed
# 14             Completed
# 15             Completed
# 16             Completed
# 17             Completed
# 18             Completed
# 19               Pending
# 20             Completed
# 21             Completed
# 22             Completed
# 23             Completed
# 24             Completed
# 25             Completed
# 26               Pending
# 27             Completed
# 28             Completed
# 29       Dismissed Rumor
# 30             Completed
# 31             Withdrawn
# 32             Completed
# 33             Completed
# 34             Completed
# 35               Pending
# 36             Completed
# 37             Completed
# 38               Pending
# 39             Completed
# 40             Completed
# 41             Completed
# 42             Completed
# 43               Pending
# 44               Pending
# 45             Withdrawn
# 46             Completed
# 47             Completed
# 48             Completed
# 49             Completed
# 50               Pending
# 51               Pending
# 52             Completed
# 53             Withdrawn
# 54             Completed
# 55             Completed
# 56               Pending
# 57             Completed
# 58             Completed
# 59             Completed
# 60               Pending
# 61               Pending
# 62             Completed
# 63             Completed
# 64               Pending
# 65             Completed
# 66               Pending
# 67             Withdrawn
# 68             Completed
# 69             Completed
# 70             Completed
# 71             Completed
# 72             Completed
# 73             Completed
# 74             Completed
# 75               Pending
# 76             Completed
# 77             Completed
# 78             Completed
# 79             Completed
# 80               Pending
# 81             Completed
# 82             Completed
# 83             Withdrawn
# 84             Completed
# 85             Completed
# 86             Completed
# 87             Completed
# 88             Completed
# 89             Completed
# 90             Withdrawn
# 91             Completed
# 92             Completed
# 93             Completed
# 94             Completed
# 95             Withdrawn
# 96               Pending
# 97               Pending
# 98             Withdrawn
# 99             Completed
# 100            Completed
# 101            Completed
# 102            Completed
# 103              Pending
# 104            Completed
# 105            Completed
# 106            Completed
# 107             Intended
# 108              Pending
# 109      Dismissed Rumor
# 110            Completed
# 111            Completed
# 112            Completed
# 113            Completed
# 114            Completed
# 115            Completed
# 116            Completed
# 117            Completed
# 118              Pending
# 119            Completed
# 120            Completed
# 121            Completed
# 122              Pending
# 123              Pending
# 124            Completed
# 125            Completed
# 126            Withdrawn
# 127            Completed
# 128            Completed
# 129            Completed
# 130            Completed
# 131            Completed
# 132            Completed
# 133            Completed
# 134            Completed
# 135            Withdrawn
# 136            Completed
# 137            Completed
# 138            Completed
# 139              Pending
# 140              Pending
# 141            Completed
# 142            Completed
# 143            Completed
# 144              Pending
# 145              Pending
# 146            Completed
# 147            Completed
# 148            Completed
# 149            Completed
# 150      Dismissed Rumor
# 151            Completed
# 152            Completed
# 153            Completed
# 154              Pending
# 155            Completed
# 156              Pending
# 157            Completed
# 158            Withdrawn
# 159            Completed
# 160            Completed
# 161            Completed
# 162            Completed
# 163              Pending
# 164            Completed
# 165            Completed
# 166            Completed
# 167            Completed
# 168            Completed
# 169            Completed
# 170            Completed
# 171            Completed
# 172      Dismissed Rumor
# 173            Completed
# 174            Completed
# 175            Completed
# 176            Completed
# 177            Completed
# 178              Pending
# 179              Pending
# 180            Completed
# 181            Completed
# 182            Completed
# 183            Completed
# 184            Completed
# 185            Completed
# 186            Completed
# 187            Completed
# 188             Intended
# 189            Completed
# 190            Withdrawn
# 191              Pending
# 192            Completed
# 193              Pending
# 194            Completed
# 195            Completed
# 196            Completed
# 197            Completed
# 198            Completed
# 199            Completed
# 200            Completed
# 201            Withdrawn
# 202            Completed
# 203            Completed
# 204            Completed
# 205            Completed
# 206            Withdrawn
# 207            Completed
# 208            Completed
# 209            Completed
# 210            Completed
# 211            Completed
# 212              Pending
# 213            Completed
# 214            Completed
# 215            Completed
# 2958           Completed
# 2959           Withdrawn
# 2960             Pending
# 2961           Completed
# 2962           Completed
# 2963           Completed
# 2964             Pending
# 2965           Completed
# 2966           Completed
# 2967           Completed
# 2968           Completed
# 2969           Completed
# 2970           Completed
# 2971           Completed
# 2972           Completed
# 2973             Pending
# 2974           Completed
# 2975           Completed
# 2976           Completed
# 2977           Completed
# 2978           Completed
# 2979           Completed
# 2980             Pending
# 2981           Completed
# 2982           Completed
# 2983            Intended
# 2984           Completed
# 2985           Completed
# 2986           Completed
# 2987           Completed
# 2988           Completed
# 2989            Intended
# 2990           Completed
# 2991            Intended
# 2992            Intended
# 2993           Completed
# 2994           Completed
# 2995           Completed
# 2996           Completed
# 2997           Completed
# 2998           Completed
# 2999     Dismissed Rumor
# 3000     Dismissed Rumor
# 3001     Dismissed Rumor
# 3002           Completed
# 3003     Dismissed Rumor
# 3004           Completed
# 3005             Pending
# 3006             Pending
# 3007           Completed
# 3008           Completed
# 3009             Pending
# 3010     Dismissed Rumor
# 3011     Dismissed Rumor
# 3012           Completed
# 3013           Completed
# 3014           Completed
# 3015           Completed
# 3016           Completed
# 3017           Completed
# 3018           Completed
# 3019           Completed
# 3020           Completed
# 3021           Completed
# 3022            Intended
# 3023             Pending
# 3024           Completed
# 3025           Completed
# 3026           Completed
# 3027           Completed
# 3028           Withdrawn
# 3029           Completed
# 3030           Completed
# 3031           Completed
# 3032             Pending
# 3033           Completed
# 3034           Completed
# 3035           Completed
# 3036           Completed
# 3037           Completed
# 3038           Completed
# 3039             Pending
# 3040           Completed
# 3041             Pending
# 3042             Pending
# 3043           Completed
# 3044           Completed
# 3045           Completed
# 3046             Pending
# 3047             Pending
# 3048           Completed
# 3049           Completed
# 3050             Pending
# 3051           Completed
# 3052     Dismissed Rumor
# 3053           Completed
# 3054           Completed
# 3055           Withdrawn
# 3056           Completed
# 3057           Completed
# 3058           Completed
# 3059           Completed
# 3060             Pending
# 3061           Completed
# 3062           Completed
# 3063           Completed
# 3064           Completed
# 3065           Completed
# 3066           Completed
# 3067           Completed
# 3068           Completed
# 3069           Completed
# 3070           Completed
# 3071            Intended
# 3072           Completed
# 3073           Withdrawn
# 3074           Completed
# 3075           Completed
# 3076           Completed
# 3077           Completed
# 3078           Completed
# 3079           Completed
# 3080           Completed
# 3081           Completed
# 3082           Completed
# 3083           Completed
# 3084             Pending
# 3085             Pending
# 3086             Pending
# 3087           Completed
# 3088           Completed
# 3089           Completed
# 3090           Completed
# 3091           Completed
# 3092             Pending
# 3093           Completed
# 3094           Completed
# 3095             Pending
# 3096           Completed
# 3097           Completed
# 3098           Withdrawn
# 3099             Pending
# 3100           Completed
# 3101           Completed
# 3102             Pending
# 3103           Completed
# 3104             Pending
# 3105           Completed
# 3106           Completed
# 3107           Completed
# 3108           Completed
# 3109             Pending
# 3110           Completed
# 3111            Intended
# 3112           Completed
# 3113           Completed
# 3114           Completed
# 3115           Completed
# 3116           Completed
# 3117           Completed
# 3118           Completed
# 3119           Completed
# 3120             Pending
# 3121             Pending
# 3122             Pending
# 3123           Completed
# 3124           Completed
# 3125           Completed
# 3126             Pending
# 3127           Completed
# 3128           Completed
# 3129            Intended
# 3130           Completed
# 3131           Completed
# 3132           Completed
# 3133           Completed
# 3134           Withdrawn
# 3135           Completed
# 3136             Pending
# 3137           Completed
# 3138           Completed
# 3139           Completed
# 3140           Completed
# 3141           Completed
# 3142           Withdrawn
# 3143           Completed
# 3144           Completed
# 3145           Completed
# 3146           Completed
# 3147           Completed
# 3148           Completed
# 3149           Completed
# 3150           Completed
# 3151           Completed
# 3152           Completed
# 3153           Completed
# 3154           Completed
# 3155             Pending
# 3156           Completed
# 3157           Completed
# 3158           Completed
# 3159           Completed
# 3160           Completed
# 3161           Completed
# 3162           Completed
# 3163           Completed
# 3164           Completed
# 3165           Completed
# 3166             Pending
# 3167           Completed
# 3168           Completed
# 3169           Completed
# 3170           Completed
# 3171           Completed
# 3172           Completed
# 3173           Completed
# 3174           Completed
# 3175           Completed
# 3176           Completed
# 3177           Completed
# 3178           Completed
# 3179           Completed
# 3180           Completed
# 3181             Pending
# 3182           Completed
# 3183           Completed
# 3184           Completed
# 3185           Completed
# 3186             Pending
# 3187             Pending
# 3188            Intended
# 3189           Completed
# 3190            Intended
# 3191           Completed
# 3192           Completed
# 3193           Completed
# 3194           Completed
# 3195           Completed
# 3196           Completed
# 3197             Pending
# 3198           Completed
# 3199           Completed
# 3200           Completed
# 3201           Completed
# 3202             Pending
# 3203             Pending
# 3204             Pending
# 3205           Completed
# 3206             Pending
# 3207             Pending
# 3208             Pending
# 3209            Intended
# 3210             Pending
# 3211           Completed
# 3212             Pending
# 3213           Completed
# 3214           Completed
# 3215           Completed
# 3216             Pending
# 3217     Dismissed Rumor
# 3218           Completed
# 3219           Completed
# 3220             Pending
# 3221             Pending
# 3222           Completed
# 3223             Pending
# 3224             Pending
# 3225             Pending
# 3226             Pending
# 3227             Pending
# 3228           Completed
# 3229           Completed
# 3230           Completed
# 3231           Completed
# 3232           Completed
# 3233           Completed
# 3234           Completed
# 3235             Pending
# 3236           Completed
# 3237             Pending
# 3238           Withdrawn
# 3239           Completed
# 3240           Completed
# 3241             Pending
# 3242           Completed
# 3243           Completed
# 3244           Completed
# 3245           Completed
# 3246           Completed
# 3247           Completed
# 3248             Pending
# 3249           Completed
# 3250           Completed
# 3251           Completed
# 3252           Completed
# 3253           Completed
# 3254           Completed
# 3255           Completed
# 3256           Completed
# 3257           Completed
# 3258           Completed
# 3259           Completed
# 3260           Completed
# 3261           Completed
# 3262           Completed
# 3263           Completed
# 3264           Completed
# 3265           Completed
# 3266           Completed
# 3267             Pending
# 3268           Completed
# 3269           Completed
# 3270           Completed
# 3271             Pending
# 3272           Completed
# 3273           Completed
# 3274           Completed
# 3275           Completed
# 3276           Completed
# 3277             Pending
# 3278             Pending
# 3279           Completed
# 3280           Completed
# 3281             Pending
# 3282           Completed
# 3283     Dismissed Rumor
# 3284            Intended
# 3285           Completed
# 3286             Pending
# 3287           Completed
# 3288           Completed
# 3289             Pending
# 3290           Completed
# 3291             Pending
# 3292           Completed
# 3293             Pending
# 3294             Pending
# 3295           Completed
# 3296            Intended
# 3297           Completed
# 3298           Completed
# 3299           Completed
# 3300           Completed
# 3301           Completed
# 3302             Pending
# 3303           Completed
# 3304           Completed
# 3305           Completed
# 3306           Completed
# 3307           Completed
# 3308           Completed
# 3309           Completed
# 3310             Pending
# 3311           Completed
# 3312           Completed
# 3313           Completed
# 3314           Completed
# 3315           Completed
# 3316           Completed
# 3317           Completed
# 3318           Completed
# 3319     Dismissed Rumor
# 3320           Completed
# 3321           Completed
# 3322             Pending
# 3323      Status Unknown
# 3324           Completed
# 3325           Completed
# 3326           Completed
# 3327           Completed
# 3328             Pending
# 3329           Completed
# 3330           Completed
# 3331           Completed
# 3332           Completed
# 3333           Completed
# 3334            Intended
# 3335            Intended
# 3336            Intended
# 3337           Completed
# 3338           Completed
# 3339           Withdrawn
# 3340           Completed
# 3341           Completed
# 3342           Completed
# 3343           Completed
# 3344             Pending
# 3345           Completed
# 3346           Completed
# 3347           Completed
# 3348           Completed
# 3349           Completed
# 3350           Completed
# 3351           Completed
# 3352           Completed
# 3353           Completed
# 3354           Completed
# 3355           Completed
# 3356           Completed
# 3357             Pending
# 3358            Intended
# 3359           Completed
# 3360           Completed
# 3361           Completed
# 3362           Completed
# 3363           Completed
# 3364            Intended
# 3365           Completed
# 3366           Completed
# 3367           Completed
# 3368           Completed
# 3369           Completed
# 3370           Withdrawn
# 3371           Completed
# 3372           Completed
# 3373           Completed
# 3374            Intended
# 3375           Completed
# 3376             Pending
# 3377           Completed
# Name: TransactionStatus, dtype: string

# %% [markdown]
# ## Filtering
# Need to ensure certain conditions are meant in order to be able to label the deal. Specifically, we need to ensure the transaction was completed, valuation data is accessible, and the deal happened at least three years ago so there is sufficient time to asess target performance after the deal was proposed.

# %%
# Convert 'TransactionEffectiveDate' to datetime if it's not already
combined_deals_df['TransactionEffectiveDate'] = pd.to_datetime(combined_deals_df['TransactionEffectiveDate'], errors='coerce')

# Calculate the date three years prior to today
three_years_prior = pd.Timestamp(datetime.now()) - pd.DateOffset(years=3)

# Filter the DataFrame based on the conditions
filtered_deals_df = combined_deals_df[
    (combined_deals_df['TransactionStatus'] == 'Completed') & 
    (combined_deals_df['PercentageOfSharesAcquired'] != 0.0) & 
    ((combined_deals_df['PricePerShare'].notna()) & (combined_deals_df['PricePerShare'] != 0.0)) |  
    ((combined_deals_df['TransactionValueIncludingNetDebtOfTarget'].notna()) & (combined_deals_df['TransactionValueIncludingNetDebtOfTarget'] != 0.0)) & 
    (combined_deals_df['TransactionEffectiveDate'] < three_years_prior) & 
    (combined_deals_df['TransactionEffectiveDate'].notna())
]

# Display the length of the filtered DataFrame and the first few rows
print(f"Length of flitered_deals_df: {len(filtered_deals_df)}")
filtered_deals_df.head()
# Out:
# Length of flitered_deals_df: 2021
#                        AcquirerName                               TargetName  \
# 2       [Abb Asea Brown Boveri Ltd]                          [ABB India Ltd]
# 3       [Abb Asea Brown Boveri Ltd]                          [ABB India Ltd]
# 6   [Tube Investments of India Ltd]  [CG Power and Industrial Solutions Ltd]
# 7                  [Carl Bennet AB]                        [Lifco AB (publ)]
# 10       [Doosan Enerbility Co Ltd]               [Doosan Enerbility Co Ltd]
#
#    TransactionEffectiveDate  PercentageOfSharesAcquired  \
# 2                2018-11-02                       5.918
# 3                2010-08-13                      22.892
# 6                2020-11-26                      56.612
# 7                2000-09-08                        78.5
# 10               2019-12-06                       6.384
#
#                          AcquirerRegion                         TargetRegion  \
# 2                                Europe  Asia Pacific Excluding Central Asia
# 3                                Europe  Asia Pacific Excluding Central Asia
# 6   Asia Pacific Excluding Central Asia  Asia Pacific Excluding Central Asia
# 7                                Europe                               Europe
# 10  Asia Pacific Excluding Central Asia  Asia Pacific Excluding Central Asia
#
#    CurrencyCodeOfTransaction             FormOfTransactionName  \
# 2                         RE   Acquisition Of Partial Interest
# 3                         RE   Acquisition Of Partial Interest
# 6                         RE  Acquisition Of Majority Interest
# 7                        SKR  Acquisition Of Majority Interest
# 10                       WON                           Buyback
#
#    TransactionStatus AcquirerPublicStatus  ...  \
# 2          Completed           Subsidiary  ...
# 3          Completed           Subsidiary  ...
# 6          Completed               Public  ...
# 7          Completed              Private  ...
# 10         Completed               Public  ...
#
#                                        DealPurpose PricePerShare  \
# 2                          [Strengthen operations]        20.164
# 3   [General restructuring of business/operations]        19.785
# 6                                              NaN         0.114
# 7                                              NaN         4.872
# 10                                         [Other]         5.461
#
#    InitialPricePerShare  PremiumAsOn1DayPriorToAnnouncementDate  \
# 2                20.164           1970-01-01 00:00:00.000000016
# 3                19.785           1970-01-01 00:00:00.000000033
# 6                 0.114           1970-01-01 00:00:00.000000000
# 7                 4.872           1970-01-01 00:00:00.000000004
# 10                5.461           1970-01-01 00:00:00.000000000
#
#     PremiumAsOn1WeekPriorToAnnouncementDate  \
# 2             1970-01-01 00:00:00.000000014
# 3             1970-01-01 00:00:00.000000028
# 6             1970-01-01 00:00:00.000000020
# 7             1970-01-01 00:00:00.000000020
# 10            1969-12-31 23:59:59.999999998
#
#     PremiumAsOn4WeeksPriorToAnnouncementDate  RatioOfRankvalueToNetIncome  \
# 2              1970-01-01 00:00:00.000000006                       62.628
# 3              1970-01-01 00:00:00.000000005                         52.3
# 6              1970-01-01 00:00:00.000000035                       -1.833
# 7              1970-01-01 00:00:00.000000010                       15.006
# 10             1969-12-31 23:59:59.999999994                      -29.279
#
#    RatioOfRankvalueToCashFlow  RatioOfRankvalueToSales  AnalystEstimatedValue
# 2                      34.009                    2.897                   <NA>
# 3                      31.847                    2.974                   <NA>
# 6                      57.024                    0.775             100.146882
# 7                       5.257                    0.444                   <NA>
# 10                      9.449                    0.717                   <NA>
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Download the Dataset
# The next step from here is to label the dataset in retroactive_dcf.ipynb and acquisition_labeling.ipynb

# %%
csv_filename = 'executed_acquisition_deals.csv'
filtered_deals_df.to_csv(csv_filename, index=False)

print(f'Data saved to {csv_filename}')
# Out:
# Data saved to executed_acquisition_deals.csv
