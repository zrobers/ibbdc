# %% [markdown]
# # Retroactive DCF Calculation
# Using actual cash flow data, rather than predicted cash flow based on growth assumptions, this notebook retroactively computes a DCF valuation for a company at the time a deal was proposed. By comparing this valuation to the terms of the proposed acquisition deal, one can determine whether the terms of the deal proved advantageous for the target or acquirer independent of overall market performance. This comarison can be used to label the acqusition dataset.

# %%
import lseg.data as ld
from lseg.data.content import search
from datetime import date, timedelta
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read the Deals Dataset

# %%
deals_df = pd.read_csv('incomplete_acquisition_deals.csv')
deals_df.head()
# Out:
#                                AcquirerName  \
# 0                          ['Comcast Corp']
# 1                          ['Chevron Corp']
# 2  ['Hong Kong Exchanges and Clearing Ltd']
# 3                   ['Xerox Holdings Corp']
# 4          ['Alimentation Couche-Tard Inc']
#
#                             TargetName TransactionAnnouncementDate  \
# 0                        ['TFCF Corp']                  2018-06-13
# 1          ['Anadarko Petroleum Corp']                  2019-04-12
# 2  ['London Stock Exchange Group PLC']                  2019-09-11
# 3                           ['HP Inc']                  2019-11-06
# 4                     ['Carrefour SA']                  2021-01-12
#
#    PercentageOfSharesAcquired                       AcquirerRegion  \
# 0                           0                             Americas
# 1                           0                             Americas
# 2                           0  Asia Pacific Excluding Central Asia
# 3                           0                             Americas
# 4                           0                             Americas
#
#   TargetRegion  PricePerShare CurrencyCodeOfTransaction  \
# 0     Americas         35.000                        US
# 1     Americas         64.996                        US
# 2       Europe        103.287                       STG
# 3     Americas         23.938                        US
# 4       Europe         24.414                       EUR
#
#                                          DealPurpose FormOfTransactionName  \
# 0  ['Sell a loss making/bankrupt operation', 'Str...                Merger
# 1  ['Create synergies, eliminate duplicate servic...                Merger
# 2  ['Expand presence in new/foreign markets', 'Cr...                Merger
# 3  ['Strengthen existing operations/expand presen...                Merger
# 4  ['Expand presence in new/foreign markets', 'St...                Merger
#
#    ...        TargetMidIndustry  AnalystEstimatedValue  \
# 0  ...                    Cable                    NaN
# 1  ...                Oil & Gas                    NaN
# 2  ...                Brokerage                    NaN
# 3  ...  Computers & Peripherals                33000.0
# 4  ...           FOOD/BEVERAGES                    NaN
#
#   RatioOfTransactionValueToNetIncome RatioOfTransactionValueToCashFlow  \
# 0                             21.308                            10.182
# 1                             62.177                             6.162
# 2                            110.412                            51.970
# 3                             11.742                             6.804
# 4                             18.949                             3.631
#
#   RatioOfTransactionValueToSales RatioOfRankvalueToNetIncome  \
# 0                          2.220                      25.457
# 1                          3.631                      63.345
# 2                         25.666                     110.412
# 3                          0.594                      11.961
# 4                          0.224                      32.799
#
#   RatioOfRankvalueToCashFlow RatioOfRankvalueToSales  \
# 0                     12.165                   2.652
# 1                      6.277                   3.699
# 2                     51.970                  25.666
# 3                      6.930                   0.606
# 4                      6.284                   0.388
#
#   TransactionValueIncludingNetDebtOfTarget  TransactionEffectiveDate
# 0                                77464.372                2018-06-13
# 1                                48712.296                2019-04-12
# 2                                37259.153                2019-09-11
# 3                                35524.904                2019-11-06
# 4                                34151.922                2021-01-12
#
# [5 rows x 28 columns]

# %% [markdown]
# # Functions to Calculate the Retroactive DCF
# $\text{DCF} = \sum_{i=1}^{n} \frac{\text{CF}_i}{(1 + r)^i} + \frac{\text{TV}}{(1 + r)^n}\\$
# These functions use the actual cash flows gather via the LSEG API rather than projected cash flows. The terminal value is implemented once there no longer is any actual cash flow data and computed with the Exit Mutliple Method Perpetuity Growth Model. A weighted averaging approach is used to estimate g (the growth rate).

# %%
# Compute the Projected Growth Rate for the Perpetuity Growth Rate using a Weighted Average Approach to include momentum
def estimate_g(n, actual_cash_flows):
    # Calculate year-on-year growth rates
    growth_rates = []
    for i in range(1, len(actual_cash_flows)):
        growth_rate = (actual_cash_flows[i] - actual_cash_flows[i - 1]) / actual_cash_flows[i - 1]
        growth_rates.append(growth_rate)
    
    # Assign weights (more recent years get higher weights)
    weights = np.arange(n, 0, -1)  # e.g., if n=4, weights = [4, 3, 2, 1]
    
    # Calculate the weighted average growth rate
    numerator = sum(rate * weight for rate, weight in zip(growth_rates, weights[:len(growth_rates)]))
    denominator = sum(weights[:len(growth_rates)])
    
    g = numerator / denominator if denominator != 0 else 0  # Avoid division by zero
    return g

# Uses Exit Mutliple Method to compute terminal value
def compute_terminal_value(ebitda_last_year, exit_multiple):
    terminal_value = ebitda_last_year * exit_multiple
    return terminal_value

def retroactive_dcf(discount_rate, n, actual_cash_flows, ebitda_last_year, exit_mutliple):
    # Estimate the growth rate
    growth_rate = estimate_g(n, actual_cash_flows)
    print(growth_rate)

    # Calculate the terminal value based on the last actual cash flow
    terminal_value = compute_terminal_value(ebitda_last_year, exit_mutliple)

    # Discount the cash flows and terminal value back to present value
    dcf_value = sum(cf / (1 + discount_rate) ** (i + 1) for i, cf in enumerate(actual_cash_flows))
    dcf_value += terminal_value / (1 + discount_rate) ** n

    return dcf_value

# %%
import lseg.data as ld
from datetime import date, timedelta

ld.open_session()

# Create date objects for today and 10 years ago
today = date.today()
five_years_ago = today - timedelta(days=365*5)

df = ld.get_history(
    universe="IBM",
    fields=["TR.F.CF"],
    interval="yearly",
    start=five_years_ago,
    end=today
)

df.head()


# fields=["TR.F.CF", "TR.CFPSMean", "TR.CFPSMedian", "TR.F.NetCashFlowOp", "TR.F.NetCashFlowInvst", "TR.NetCashFlowFin", "TR.MnATargetSharesOutstandingMRQ", "TR.CompanyMarketCap"],
# Out:
# IBM           Cash Flow
# Date
# 2018-12-31  15240000000
# 2019-12-31  13351000000
# 2020-12-31  10737000000
# 2021-12-31  11041000000
# 2022-12-31   6655000000

# %% [markdown]
# ## Functions to Obtain Yearly Cash Flow Data, EBITDA closest to the time of the deal, and EBITDA Exit Multiplier From the LSEG API

# %%
def obtain_cash_flow_data(company_ticker, deal_date, end_date=date.today()):

    ld.open_session() # Must be running LSEG Desktop App

    df = ld.get_history(
        universe=company_ticker,
        fields=["TR.F.CF"],
        interval="yearly",
        start=deal_date,
        end=end_date
    )

    ld.close_session()

    return df

def obtain_most_recent_ebitda(company_ticker, deal_date):

    ld.open_session()

    # date object for one year prior to deal
    one_year_before_deal = deal_date - timedelta(days=365)

    df = ld.get_history(
        universe=company_ticker,
        fields=["TR.EBITDAActValue"],
        interval="monthly",
        start=one_year_before_deal,
        end=deal_date
    )

    print(df)
    most_recent_ebitda = df.iloc[-1, 0]

    ld.close_session()

    return most_recent_ebitda

def obtain_ebitda_exit_mutliple(common_name):
    
    sector_ebitda_exit_multiples = {
    "Energy": 5.5,
    "Materials": 6.0,
    "Industrials": 7.0,
    "Consumer Discretionary": 8.5,
    "Consumer Staples": 10.5,
    "Health Care": 12.0,
    "Financials": 8.0,
    "Information Technology": 12.5,
    "Communication Services": 8.0,
    "Utilities": 7.5,
    "Real Estate": 16.0
    }

    ld.open_session()

    try:
        gics_df = ld.discovery.search(
            view=ld.discovery.Views.ORGANISATIONS,
            select="GicsName",
            filter=f"CommonName eq '{common_name}'",
            top=10000
        )

        gics_sector = gics_df.iloc[0, 0][0]  # Adjust indexing if needed
    except Exception as e:
        print(f"Error occurred: {e}")  # Optional: log the error for debugging
        return 8.0  # Return default value if search fails
    finally:
        ld.close_session()

    return sector_ebitda_exit_multiples.get(gics_sector, 8.0)  # Return default if sector not found

# %% [markdown]
# ## Test Case: Retroactive DCF for Apple (AAPL) with cash flow data obtained via the LSEG API

# %%
ticker = "AAPL.O"
deal_date = date.today() - timedelta(days=365*10)

cash_flow_df = obtain_cash_flow_data(ticker, deal_date)
cash_flows = cash_flow_df['Cash Flow'].values
print(cash_flows)

recent_ebitda = obtain_most_recent_ebitda(ticker, deal_date)
print(recent_ebitda)

# exit_mult = obtain_ebitda_exit_mutliple(ticker, deal_date)
# print(exit_mult)

valuation = retroactive_dcf(0.1, 10, cash_flows, recent_ebitda, 12.5)

print(f"The Rectroactive DCF Valuation for Apple Inc 10 Years Ago is: ${valuation}")
# Out:
# <IntegerArray>
# [ 47510000000,  64651000000,  56192000000,  58508000000,  71934000000,
#   67803000000,  68467000000, 105964000000, 110907000000, 108514000000]
# Length: 10, dtype: Int64
# AAPL.O               EBITDA - Actual
# Date
# 2013-10-28 16:30:00      58009000000
# 2014-10-20 16:30:00      60449000000
# 60449000000
# 0.11774428413889908
# The Rectroactive DCF Valuation for Apple Inc 10 Years Ago is: $726500453245.9514

# %% [markdown]
# ## Find the company ticker so we can execute a get_history() search

# %%
def find_ticker(company_name, deal_date):
    
    ld.close_session()
    ld.open_session()

    print(f"Company Name: {company_name}")

    try:
        ticker_df = ld.discovery.search(
            view=ld.discovery.Views.ORGANISATIONS,
            select="PrimaryRICTickerSymbol", 
            filter=f"CommonName eq '{company_name}'",
            top=10000
        )
    except Exception as e:
        return "NO_TICKER_FOUND"
    
    if ticker_df.empty:
        return "NO_TICKER_FOUND"

    partial_ticker = ticker_df.iloc[0,0] # Ticker but doesn't contain a suffix which is often necessary for a Python Data Library get_history() search
    print(f"PARTIAL_TICKER: {partial_ticker}")

    ordinary_share_suffixes = [
        "",       # No suffix (common for NYSE, NASDAQ, most U.S. stocks)
        ".O",     # NASDAQ (e.g., AAPL.O for Apple Inc.)
        ".N",     # NYSE (e.g., IBM.N for IBM)
        ".L",     # London Stock Exchange (LSE) (e.g., BP.L for BP)
        ".T",     # Tokyo Stock Exchange (TSE) (e.g., 7203.T for Toyota)
        ".HK",    # Hong Kong Stock Exchange (HKEX) (e.g., 0005.HK for HSBC)
        ".AX",    # Australian Securities Exchange (ASX) (e.g., CBA.AX for Commonwealth Bank)
        ".TO",    # Toronto Stock Exchange (TSX) (e.g., RY.TO for Royal Bank of Canada)
        ".PA",    # Euronext Paris (e.g., AIR.PA for Airbus)
        ".F",     # Frankfurt Stock Exchange (FSE) (e.g., BMW.F for BMW)
        ".SI",    # Singapore Exchange (SGX) (e.g., D05.SI for DBS Group)
        ".SW",    # SIX Swiss Exchange (e.g., NESN.SW for Nestlé)
        ".DE",    # Xetra (Deutsche Börse) (e.g., VOW3.DE for Volkswagen)
        ".MI",    # Borsa Italiana (Milan Stock Exchange) (e.g., ENI.MI for Eni S.p.A.)
        ".KS",    # Korea Exchange (KRX) (e.g., 005930.KS for Samsung)
        ".KQ",    # KOSDAQ (Korean secondary market) (e.g., 035720.KQ for Kakao)
        ".SA",    # B3 - Brazil Stock Exchange (B3 S.A.) (e.g., PETR4.SA for Petrobras)
        ".IS",    # Borsa Istanbul (e.g., THYAO.IS for Turkish Airlines)
        ".OL",    # Oslo Stock Exchange (e.g., EQNR.OL for Equinor)
        ".MC",    # Madrid Stock Exchange (BME) (e.g., SAN.MC for Santander)
        ".ST",    # Stockholm Stock Exchange (OMX Stockholm) (e.g., VOLVb.ST for Volvo)
        ".AS",    # Euronext Amsterdam (e.g., RDSA.AS for Royal Dutch Shell)
        ".NZ",    # New Zealand Exchange (NZX) (e.g., FPH.NZ for Fisher & Paykel)
        ".BR",    # Euronext Brussels (e.g., ABI.BR for Anheuser-Busch InBev)
        ".AT",    # Vienna Stock Exchange (e.g., OMV.AT for OMV Group)
        ".VN",    # Ho Chi Minh Stock Exchange (HOSE) (e.g., VIC.VN for Vingroup)
        ".J",     # Johannesburg Stock Exchange (JSE) (e.g., MTN.J for MTN Group)
        ".JK",    # Indonesia Stock Exchange (IDX) (e.g., BBCA.JK for Bank Central Asia)
        ".TW",    # Taiwan Stock Exchange (TWSE) (e.g., 2330.TW for TSMC)
        ".Z",     # Zurich (Swiss Market) (e.g., NESN.Z for Nestlé on Swiss Market)
    ]

    # Now, we try to find the appropriate suffix for the partial ticker
    for suffix in ordinary_share_suffixes:
        
        possible_ticker = partial_ticker + suffix

        try:
            # Attempt to obtain cash flow data
            cash_flow_data = obtain_cash_flow_data(possible_ticker, deal_date)
            if not isinstance(cash_flow_data, str):  # Check if it's not an error message
                return possible_ticker  # Return the valid ticker if data retrieval succeeds
        except Exception as e:
            # Handle exceptions that may arise during cash flow data retrieval
            continue  # Skip to the next suffix if it fails

    return "NO_TICKER_FOUND"  # If no valid ticker is found

# Test
deal_date = date.today() - timedelta(days=365*10)
print(find_ticker("Newmont Corporation", deal_date))
# Out:
# Company Name: Newmont Corporation
# PARTIAL_TICKER: NEM
# NEM

# %% [markdown]
# ## Gather Cash Flow Data Using the LSEG API and then Compute the Retroactive DCF
# We create a new dataframe where the search process does not fail

# %%
# Add new columns for Ticker and RetroactiveDCFValuation
deals_df['Ticker'] = None
deals_df['RetroactiveDCFValuation'] = None

# Define the discount rate 
discount_rate = 0.1  # 10%

# Iterate through the DataFrame row by row
rows_to_drop = []  # Store indices of rows to drop

for index, row in deals_df.iterrows():
    company_name = row['TargetName'].strip("[]'\"")
    transaction_date = date.fromisoformat(row['TransactionAnnouncementDate'])

    print(f"Processing {company_name} with transaction date {transaction_date}")

    # Find the ticker using the find_ticker function
    ticker = find_ticker(company_name, transaction_date)

    if ticker == "NO_TICKER_FOUND":
        print(f"Could not find ticker for {company_name}. Marking row for deletion.")
        rows_to_drop.append(index)  # Mark this row for deletion
        continue  # Skip to the next iteration

    deals_df.at[index, 'Ticker'] = ticker  # Add the ticker to the DataFrame
    print(f"Found ticker: {ticker} for {company_name}")

    try:
        # Obtain cash flow data
        cash_flow_data = obtain_cash_flow_data(ticker, transaction_date)

        # Check if cash flow data is not empty
        if cash_flow_data.empty:
            print(f"No cash flow data found for ticker {ticker}. Marking row for deletion.")
            rows_to_drop.append(index)  # Mark this row for deletion
            continue  # Skip to the next iteration

        # Get actual cash flows as a list
        actual_cash_flows = cash_flow_data['Cash Flow'].tolist()
        print(f"Retrieved cash flow data for {ticker}: {actual_cash_flows}")

        # Obtain the most recent EBITDA
        most_recent_ebitda = obtain_most_recent_ebitda(ticker, transaction_date)
        print(f"Most recent EBITDA for {ticker}: {most_recent_ebitda}")

        # Obtain the exit multiple 
        exit_multiple = obtain_ebitda_exit_mutliple(company_name)
        print(f"Exit multiple for {ticker}: {exit_multiple}")

        # Compute the retroactive DCF valuation
        n = len(actual_cash_flows)  # Number of years of cash flows
        retroactive_valuation = retroactive_dcf(discount_rate, n, actual_cash_flows, most_recent_ebitda, exit_multiple)
        print(f"Computed retroactive DCF valuation for {ticker}: {retroactive_valuation}")

        # Add the computed valuation to the DataFrame
        deals_df.at[index, 'RetroactiveDCFValuation'] = retroactive_valuation

    except Exception as e:
        print(f"Error processing {company_name}: {e}")  # Log the error for debugging
        rows_to_drop.append(index)  # Mark this row for deletion

# Drop rows marked for deletion
deals_df.drop(index=rows_to_drop, inplace=True)

# Display the updated DataFrame
print("Updated deals DataFrame:")
print(deals_df.head())
# Out:
# Processing TFCF Corp with transaction date 2018-06-13
# Company Name: TFCF Corp
# Could not find ticker for TFCF Corp. Marking row for deletion.
# Processing Anadarko Petroleum Corp with transaction date 2019-04-12
# Company Name: Anadarko Petroleum Corp
# Could not find ticker for Anadarko Petroleum Corp. Marking row for deletion.
# Processing London Stock Exchange Group PLC with transaction date 2019-09-11
# Company Name: London Stock Exchange Group PLC
# PARTIAL_TICKER: LSEG
# Found ticker: LSEG.L for London Stock Exchange Group PLC
# Retrieved cash flow data for LSEG.L: [847000000, 834000000, 727000000, 2127000000, 2849000000]
# LSEG.L               EBITDA - Actual
# Date
# 2018-03-02 07:01:00        915000000
# 2019-03-01 07:02:00       1066000000
# Most recent EBITDA for LSEG.L: 1066000000
# Exit multiple for LSEG.L: 8.0
# 0.41900900033116795
# Computed retroactive DCF valuation for LSEG.L: 10522453570.608065
# Processing HP Inc with transaction date 2019-11-06
# Company Name: HP Inc
# PARTIAL_TICKER: HPQ
# Found ticker: HPQ for HP Inc
# Retrieved cash flow data for HPQ: [3818000000, 3633000000, 7326000000, 3912000000, 4113000000]
# HPQ                  EBITDA - Actual
# Date
# 2018-11-29 16:05:00       4635000000
# Most recent EBITDA for HPQ: 4635000000
# Exit multiple for HPQ: 12.5
# 0.1806081430780713
# Computed retroactive DCF valuation for HPQ: 53177947855.027275
# Processing Carrefour SA with transaction date 2021-01-12
# Company Name: Carrefour SA
# PARTIAL_TICKER: CA
# Could not find ticker for Carrefour SA. Marking row for deletion.
# Processing Kansas City Southern with transaction date 2021-04-20
# Company Name: Kansas City Southern
# Could not find ticker for Kansas City Southern. Marking row for deletion.
# Processing Willis Towers Watson PLC with transaction date 2020-03-09
# Company Name: Willis Towers Watson PLC
# PARTIAL_TICKER: WTW
# Found ticker: WTW.O for Willis Towers Watson PLC
# Retrieved cash flow data for WTW.O: [1577000000, 1592000000, 2806000000, 1631000000]
# WTW.O                EBITDA - Actual
# Date
# 2019-02-07 06:00:00       2036000000
# 2020-02-06 06:43:00       2300000000
# Most recent EBITDA for WTW.O: 2300000000
# Exit multiple for WTW.O: 8.0
# 0.16536047513677868
# Computed retroactive DCF valuation for WTW.O: 18538970698.72276
# Processing Unilever PLC with transaction date 2018-03-15
# Company Name: Unilever PLC
# PARTIAL_TICKER: ULVR
# Found ticker: ULVR.L for Unilever PLC
# Retrieved cash flow data for ULVR.L: [7446000000, 12033000000, 7990000000, 8091000000, 8367000000, 10181000000]
# ULVR.L               EBITDA - Actual
# Date
# 2017-01-26 07:08:00       9510000000
# 2018-02-01 07:00:00      10935000000
# Most recent EBITDA for ULVR.L: 10935000000
# Exit multiple for ULVR.L: 10.5
# 0.1301378326686319
# Computed retroactive DCF valuation for ULVR.L: 103996629390.68987
# Processing Entain PLC with transaction date 2021-09-21
# Company Name: Entain PLC
# PARTIAL_TICKER: ENT
# Found ticker: ENT.O for Entain PLC
# Retrieved cash flow data for ENT.O: [-61477000]
# Error processing Entain PLC: Unable to resolve all requested identifiers in ['ENT.O'].
# Processing Hartford Financial Services Group Inc with transaction date 2021-03-18
# Company Name: Hartford Financial Services Group Inc
# PARTIAL_TICKER: HIG
# Found ticker: HIG for Hartford Financial Services Group Inc
# Retrieved cash flow data for HIG: [2272000000, 3024000000, 2419000000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Hartford Financial Services Group Inc: index -1 is out of bounds for axis 0 with size 0
# Processing Newmont Corporation with transaction date 2019-02-22
# Company Name: Newmont Corporation
# PARTIAL_TICKER: NEM
# Found ticker: NEM for Newmont Corporation
# Retrieved cash flow data for NEM: [1486000000, 4916000000, 4928000000, 2499000000, 1786000000]
# NEM                  EBITDA - Actual
# Date
# 2018-02-22 06:55:00       2653000000
# Most recent EBITDA for NEM: 2653000000
# Exit multiple for NEM: 6.0
# 0.6786780286284649
# Computed retroactive DCF valuation for NEM: 21815840075.50403
# Processing Shaw Communications Inc with transaction date 2021-04-23
# Company Name: Shaw Communications Inc
# Could not find ticker for Shaw Communications Inc. Marking row for deletion.
# Processing Five9 Inc with transaction date 2021-07-18
# Company Name: Five9 Inc
# PARTIAL_TICKER: FIVN
# Found ticker: FIVN.O for Five9 Inc
# Retrieved cash flow data for FIVN.O: [-17043000, -14268000, -49950000]
# FIVN.O               EBITDA - Actual
# Date
# 2020-02-19 16:05:00         60820000
# 2021-02-22 16:05:00         85681000
# Most recent EBITDA for FIVN.O: 85681000
# Exit multiple for FIVN.O: 12.5
# 0.9026423492114908
# Computed retroactive DCF valuation for FIVN.O: 739853996.9947406
# Processing Renault SA with transaction date 2019-05-27
# Company Name: Renault SA
# PARTIAL_TICKER: RNO
# Found ticker: RNO.L for Renault SA
# Retrieved cash flow data for RNO.L: [15500000, 14800000, 15500000, 19700000, 22900000]
# RNO.L                EBITDA - Actual
# Date
# 2018-05-29 07:00:00         22400000
# Most recent EBITDA for RNO.L: 22400000
# Exit multiple for RNO.L: 8.5
# 0.07865421855924559
# Computed retroactive DCF valuation for RNO.L: 183865576.74277088
# Processing WM Morrison Supermarkets Ltd with transaction date 2021-07-03
# Company Name: WM Morrison Supermarkets Ltd
# PARTIAL_TICKER: MRW
# Found ticker: MRW.L for WM Morrison Supermarkets Ltd
# Retrieved cash flow data for MRW.L: [635000000, 582000000]
# Error processing WM Morrison Supermarkets Ltd: Unable to resolve all requested identifiers in ['MRW.L'].
# Processing Entain PLC with transaction date 2021-01-04
# Company Name: Entain PLC
# PARTIAL_TICKER: ENT
# Found ticker: ENT.O for Entain PLC
# Retrieved cash flow data for ENT.O: [-61477000]
# Error processing Entain PLC: Unable to resolve all requested identifiers in ['ENT.O'].
# Processing Ausnet Pty Ltd with transaction date 2021-09-21
# Company Name: Ausnet Pty Ltd
# PARTIAL_TICKER: <NA>
# Could not find ticker for Ausnet Pty Ltd. Marking row for deletion.
# Processing Inter Pipeline Ltd (Pre-Merger) with transaction date 2021-06-01
# Company Name: Inter Pipeline Ltd (Pre-Merger)
# Could not find ticker for Inter Pipeline Ltd (Pre-Merger). Marking row for deletion.
# Processing Qiagen NV with transaction date 2020-03-03
# Company Name: Qiagen NV
# PARTIAL_TICKER: QGEN
# Found ticker: QGEN.N for Qiagen NV
# Retrieved cash flow data for QGEN.N: [190003000, 541018000, 702370000, 606425000]
# QGEN.N               EBITDA - Actual
# Date
# 2019-02-04 16:04:00        513936000
# 2020-02-04 16:05:00        551758000
# Most recent EBITDA for QGEN.N: 551758000
# Exit multiple for QGEN.N: 12.0
# 0.8901313902472077
# Computed retroactive DCF valuation for QGEN.N: 6084047382.692437
# Processing Edp SA with transaction date 2018-05-11
# Company Name: Edp SA
# PARTIAL_TICKER: EDP
# Found ticker: EDP.F for Edp SA
# Retrieved cash flow data for EDP.F: [3213599000, 2387972000, 2429759000, 2857034000, 2899201000, 3220903000]
# EDP.F                EBITDA - Actual
# Date
# 2017-03-02 17:05:00       3759000000
# 2018-03-01 18:15:00       3993576000
# Most recent EBITDA for EDP.F: 3993576000
# Exit multiple for EDP.F: 7.5
# -0.024220013218344338
# Computed retroactive DCF valuation for EDP.F: 29197203821.765087
# Processing Qualcomm Inc with transaction date 2017-11-06
# Company Name: Qualcomm Inc
# PARTIAL_TICKER: QCOM
# Found ticker: QCOM.O for Qualcomm Inc
# Retrieved cash flow data for QCOM.O: [3905000000, -2960000000, 5787000000, 6591000000, 10625000000, 14768000000, 9157000000]
# QCOM.O               EBITDA - Actual
# Date
# 2016-11-02 16:03:00       9262000000
# Most recent EBITDA for QCOM.O: 9262000000
# Exit multiple for QCOM.O: 12.5
# -0.9808768136659635
# Computed retroactive DCF valuation for QCOM.O: 88996629528.7294
# Processing Meggitt Ltd with transaction date 2021-08-11
# Company Name: Meggitt Ltd
# PARTIAL_TICKER: MGGT
# Found ticker: MGGT.L for Meggitt Ltd
# Retrieved cash flow data for MGGT.L: [-116900000, 221600000]
# Error processing Meggitt Ltd: Unable to resolve all requested identifiers in ['MGGT.L'].
# Processing APA Group with transaction date 2018-06-13
# Company Name: APA Group
# PARTIAL_TICKER: APA
# Found ticker: APA.O for APA Group
# Retrieved cash flow data for APA.O: [3896000000, 2955000000, -1002000000, -3132000000, 2673000000, 5315000000]
# APA.O                EBITDA - Actual
# Date
# 2017-02-23 07:28:00       3113000000
# 2018-02-22 08:00:00       3730000000
# Most recent EBITDA for APA.O: 3730000000
# Exit multiple for APA.O: 7.5
# -0.16125779222695186
# Computed retroactive DCF valuation for APA.O: 23543011197.46934
# Processing Swedish Orphan Biovitrum AB (publ) with transaction date 2021-09-02
# Company Name: Swedish Orphan Biovitrum AB (publ)
# PARTIAL_TICKER: SOBI
# Could not find ticker for Swedish Orphan Biovitrum AB (publ). Marking row for deletion.
# Processing Sky Ltd with transaction date 2018-04-12
# Company Name: Sky Ltd
# PARTIAL_TICKER: SKYGOLD
# Could not find ticker for Sky Ltd. Marking row for deletion.
# Processing METRO AG with transaction date 2019-06-21
# Company Name: METRO AG
# PARTIAL_TICKER: B4B
# Found ticker: B4B.F for METRO AG
# Retrieved cash flow data for B4B.F: [1245000000, 645000000, 722000000, 460000000, 1247000000]
# B4B.F                EBITDA - Actual
# Date
# 2017-12-13 06:18:00       1810000000
# 2018-12-13 08:10:00       1525000000
# Most recent EBITDA for B4B.F: 1525000000
# Exit multiple for B4B.F: 10.5
# 0.028641235484507015
# Computed retroactive DCF valuation for B4B.F: 13238303084.116207
# Processing CoreLogic Inc with transaction date 2021-02-16
# Company Name: CoreLogic Inc
# Could not find ticker for CoreLogic Inc. Marking row for deletion.
# Processing Tegna Inc with transaction date 2020-03-17
# Company Name: Tegna Inc
# PARTIAL_TICKER: TGNA
# Found ticker: TGNA.N for Tegna Inc
# Retrieved cash flow data for TGNA.N: [396864000, 617333000, 606049000, 752275000]
# TGNA.N               EBITDA - Actual
# Date
# 2019-03-01 07:34:00        780849000
# 2020-02-11 08:01:00        707512000
# Most recent EBITDA for TGNA.N: 707512000
# Exit multiple for TGNA.N: 8.0
# 0.2944256123550951
# Computed retroactive DCF valuation for TGNA.N: 5706047274.093298
# Processing Intu Properties PLC with transaction date 2018-10-04
# Company Name: Intu Properties PLC
# PARTIAL_TICKER: INTU
# Found ticker: INTU.O for Intu Properties PLC
# Retrieved cash flow data for INTU.O: [1553000000, 1782000000, 2044000000, 2425000000, 2812000000, 3190000000]
# INTU.O               EBITDA - Actual
# Date
# 2017-08-22 16:00:00       1959000000
# 2018-08-23 16:09:00       2213000000
# Most recent EBITDA for INTU.O: 2213000000
# Error occurred: index 0 is out of bounds for axis 0 with size 0
# Exit multiple for INTU.O: 8.0
# 0.15565379167660806
# Computed retroactive DCF valuation for INTU.O: 19616689591.83454
# Processing Hexcel Corp with transaction date 2020-01-12
# Company Name: Hexcel Corp
# PARTIAL_TICKER: HXL
# Found ticker: HXL for Hexcel Corp
# Retrieved cash flow data for HXL: [448700000, 172600000, 155500000, 252500000]
# HXL                  EBITDA - Actual
# Date
# 2019-01-23 16:20:00        502000000
# Most recent EBITDA for HXL: 502000000
# Exit multiple for HXL: 7.0
# -0.16788481311808814
# Computed retroactive DCF valuation for HXL: 3239953350.180998
# Processing Crown Resorts Ltd with transaction date 2021-05-10
# Company Name: Crown Resorts Ltd
# PARTIAL_TICKER: CWN
# Could not find ticker for Crown Resorts Ltd. Marking row for deletion.
# Processing Signature Aviation Ltd with transaction date 2021-01-11
# Company Name: Signature Aviation Ltd
# PARTIAL_TICKER: SIG
# Found ticker: SIG for Signature Aviation Ltd
# Retrieved cash flow data for SIG: [127300000, 898900000, 506700000]
# SIG                  EBITDA - Actual
# Date
# 2019-04-03 06:52:00        458700000
# 2020-03-26 06:50:00        496300000
# Most recent EBITDA for SIG: 496300000
# Error occurred: index 0 is out of bounds for axis 0 with size 0
# Exit multiple for SIG: 8.0
# 3.4622391319337056
# Computed retroactive DCF valuation for SIG: 4222331329.827196
# Processing Scor SE with transaction date 2018-09-04
# Company Name: Scor SE
# PARTIAL_TICKER: SCR
# Found ticker: SCR.N for Scor SE
# Retrieved cash flow data for SCR.N: [-2105000, -6296000, -32533000]
# Error processing Scor SE: Unable to resolve all requested identifiers in ['SCR.N'].
# Processing TXNM Energy Inc with transaction date 2020-10-21
# Company Name: TXNM Energy Inc
# PARTIAL_TICKER: TXNM
# Found ticker: TXNM.N for TXNM Energy Inc
# Retrieved cash flow data for TXNM.N: [392671000, 501456000, 531529000, 525775000]
# TXNM.N               EBITDA - Actual
# Date
# 2019-02-27 06:30:00        550026000
# 2020-02-28 06:30:00        565325000
# Most recent EBITDA for TXNM.N: 565325000
# Exit multiple for TXNM.N: 7.5
# 0.14071305527567868
# Computed retroactive DCF valuation for TXNM.N: 4425791449.354551
# Processing Ampol Ltd with transaction date 2019-11-26
# Company Name: Ampol Ltd
# PARTIAL_TICKER: ALD
# Found ticker: ALD.AX for Ampol Ltd
# Retrieved cash flow data for ALD.AX: [817005000, 771177000, -57500000, 924600000, 1217000000]
# ALD.AX               EBITDA - Actual
# Date
# 2018-02-26 12:30:00       1164163000
# 2019-02-26 03:32:00       1082000000
# Most recent EBITDA for ALD.AX: 1082000000
# Exit multiple for ALD.AX: 5.5
# -3.941872791704295
# Computed retroactive DCF valuation for ALD.AX: 6419145865.284908
# Processing G4S Ltd with transaction date 2020-09-14
# Company Name: G4S Ltd
# PARTIAL_TICKER: G4S
# Could not find ticker for G4S Ltd. Marking row for deletion.
# Processing Coherent Inc with transaction date 2021-01-19
# Company Name: Coherent Inc
# Could not find ticker for Coherent Inc. Marking row for deletion.
# Processing Just Eat Ltd with transaction date 2019-10-22
# Company Name: Just Eat Ltd
# PARTIAL_TICKER: JE.
# Could not find ticker for Just Eat Ltd. Marking row for deletion.
# Processing Crown Resorts Ltd with transaction date 2019-04-09
# Company Name: Crown Resorts Ltd
# PARTIAL_TICKER: CWN
# Could not find ticker for Crown Resorts Ltd. Marking row for deletion.
# Processing Eutelsat Communications SA with transaction date 2021-09-29
# Company Name: Eutelsat Communications SA
# PARTIAL_TICKER: ETL
# Found ticker: ETL.L for Eutelsat Communications SA
# Retrieved cash flow data for ETL.L: [735800000, 721800000, 783900000]
# ETL.L                EBITDA - Actual
# Date
# 2020-07-31 06:35:00       1060600000
# 2021-07-30 16:38:00        921900000
# Most recent EBITDA for ETL.L: 921900000
# Exit multiple for ETL.L: 8.0
# 0.02299781939551773
# Computed retroactive DCF valuation for ETL.L: 7395490608.564987
# Processing Entra ASA with transaction date 2020-11-24
# Company Name: Entra ASA
# PARTIAL_TICKER: ENTRA
# Found ticker: ENTRA.IS for Entra ASA
# Retrieved cash flow data for ENTRA.IS: [<NA>, <NA>, -3190842000, 3913797000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Entra ASA: index -1 is out of bounds for axis 0 with size 0
# Processing Coherent Inc with transaction date 2021-02-08
# Company Name: Coherent Inc
# Could not find ticker for Coherent Inc. Marking row for deletion.
# Processing Entra ASA with transaction date 2020-11-25
# Company Name: Entra ASA
# PARTIAL_TICKER: ENTRA
# Found ticker: ENTRA.IS for Entra ASA
# Retrieved cash flow data for ENTRA.IS: [<NA>, <NA>, -3190842000, 3913797000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Entra ASA: index -1 is out of bounds for axis 0 with size 0
# Processing Infratil Ltd with transaction date 2020-12-08
# Company Name: Infratil Ltd
# PARTIAL_TICKER: IFT
# Found ticker: IFT.AX for Infratil Ltd
# Retrieved cash flow data for IFT.AX: [162500000, 25300000, 248600000, 669900000]
# IFT.AX               EBITDA - Actual
# Date
# 2019-05-17 02:21:00        477500000
# 2020-05-28 03:06:00        497900000
# Most recent EBITDA for IFT.AX: 497900000
# Exit multiple for IFT.AX: 8.0
# 2.9433789590342108
# Computed retroactive DCF valuation for IFT.AX: 3533543132.299705
# Processing CoreLogic Inc with transaction date 2020-06-26
# Company Name: CoreLogic Inc
# Could not find ticker for CoreLogic Inc. Marking row for deletion.
# Processing Scout24 SE with transaction date 2019-01-18
# Company Name: Scout24 SE
# PARTIAL_TICKER: G24
# Could not find ticker for Scout24 SE. Marking row for deletion.
# Processing Cogeco Communications Inc with transaction date 2020-09-02
# Company Name: Cogeco Communications Inc
# PARTIAL_TICKER: CCA
# Found ticker: CCA.AX for Cogeco Communications Inc
# Retrieved cash flow data for CCA.AX: [-3500159, -2841929, -2673626, -1634492]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Cogeco Communications Inc: index -1 is out of bounds for axis 0 with size 0
# Processing Paramount Group Inc with transaction date 2020-11-16
# Company Name: Paramount Group Inc
# PARTIAL_TICKER: PGRE
# Found ticker: PGRE.N for Paramount Group Inc
# No cash flow data found for ticker PGRE.N. Marking row for deletion.
# Processing TKS Holding MKPAO with transaction date 2020-09-22
# Company Name: TKS Holding MKPAO
# PARTIAL_TICKER: TCSG
# Could not find ticker for TKS Holding MKPAO. Marking row for deletion.
# Processing Soho China Ltd with transaction date 2020-03-10
# Company Name: Soho China Ltd
# PARTIAL_TICKER: 410
# Could not find ticker for Soho China Ltd. Marking row for deletion.
# Processing Rpc Group Ltd with transaction date 2019-01-23
# Company Name: Rpc Group Ltd
# PARTIAL_TICKER: RPC
# Could not find ticker for Rpc Group Ltd. Marking row for deletion.
# Processing Douyu International Holdings Ltd with transaction date 2020-08-10
# Company Name: Douyu International Holdings Ltd
# PARTIAL_TICKER: DOYU
# Found ticker: DOYU.O for Douyu International Holdings Ltd
# Retrieved cash flow data for DOYU.O: [123469942, 515652186, -531516257, -2920292]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Douyu International Holdings Ltd: index -1 is out of bounds for axis 0 with size 0
# Processing Rogers Corp with transaction date 2021-11-02
# Company Name: Rogers Corp
# PARTIAL_TICKER: ROG
# Found ticker: ROG for Rogers Corp
# Retrieved cash flow data for ROG: [121415000, 151433000, 162529000]
# ROG                  EBITDA - Actual
# Date
# 2020-02-20 16:09:00        188200000
# 2021-02-18 16:09:00        177000000
# Most recent EBITDA for ROG: 177000000
# Exit multiple for ROG: 12.5
# 0.1776501460811774
# Computed retroactive DCF valuation for ROG: 2019922952.667167
# Processing Unizo Holdings Co Ltd with transaction date 2019-10-10
# Company Name: Unizo Holdings Co Ltd
# PARTIAL_TICKER: 3258
# Could not find ticker for Unizo Holdings Co Ltd. Marking row for deletion.
# Processing Siltronic AG with transaction date 2020-11-29
# Company Name: Siltronic AG
# PARTIAL_TICKER: WAF
# Found ticker: WAF.AX for Siltronic AG
# Retrieved cash flow data for WAF.AX: [-4150000, 123739000, 271732000, 243152000]
# WAF.AX               EBITDA - Actual
# Date
# 2020-03-26 13:22:00         -4145000
# Most recent EBITDA for WAF.AX: -4145000
# Exit multiple for WAF.AX: 12.5
# -13.320981368562226
# Computed retroactive DCF valuation for WAF.AX: 433334635.61232144
# Processing AMP Ltd with transaction date 2020-10-30
# Company Name: AMP Ltd
# PARTIAL_TICKER: AMP
# Found ticker: AMP for AMP Ltd
# Retrieved cash flow data for AMP: [2077000000, 1741000000, 3608000000, 3346000000]
# AMP                  EBITDA - Actual
# Date
# 2019-01-30 16:15:00       2333000000
# 2020-01-29 16:10:00       2998000000
# Most recent EBITDA for AMP: 2998000000
# Exit multiple for AMP: 8.0
# 0.26942184875225433
# Computed retroactive DCF valuation for AMP: 24704526330.168697
# Processing Cuscaden Peak Investments Pte Ltd with transaction date 2021-08-02
# Company Name: Cuscaden Peak Investments Pte Ltd
# PARTIAL_TICKER: T39
# Could not find ticker for Cuscaden Peak Investments Pte Ltd. Marking row for deletion.
# Processing MEG Energy Corp with transaction date 2018-09-30
# Company Name: MEG Energy Corp
# PARTIAL_TICKER: MEG
# Found ticker: MEG for MEG Energy Corp
# Retrieved cash flow data for MEG: [8279000, 7424000, 4148000, -51960000, 3085000, -740000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing MEG Energy Corp: index -1 is out of bounds for axis 0 with size 0
# Processing Welbilt Inc with transaction date 2021-04-21
# Company Name: Welbilt Inc
# Could not find ticker for Welbilt Inc. Marking row for deletion.
# Processing Anixter International Inc with transaction date 2019-10-30
# Company Name: Anixter International Inc
# Could not find ticker for Anixter International Inc. Marking row for deletion.
# Processing Surveymonkey Global Inc with transaction date 2021-10-28
# Company Name: Surveymonkey Global Inc
# Could not find ticker for Surveymonkey Global Inc. Marking row for deletion.
# Processing Cogeco Inc with transaction date 2020-09-02
# Company Name: Cogeco Inc
# PARTIAL_TICKER: CCA
# Found ticker: CCA.AX for Cogeco Inc
# Retrieved cash flow data for CCA.AX: [-3500159, -2841929, -2673626, -1634492]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Cogeco Inc: index -1 is out of bounds for axis 0 with size 0
# Processing QEP Resources Inc with transaction date 2019-01-07
# Company Name: QEP Resources Inc
# Could not find ticker for QEP Resources Inc. Marking row for deletion.
# Processing Unizo Holdings Co Ltd with transaction date 2019-08-16
# Company Name: Unizo Holdings Co Ltd
# PARTIAL_TICKER: 3258
# Could not find ticker for Unizo Holdings Co Ltd. Marking row for deletion.
# Processing Versum Materials Inc with transaction date 2019-01-28
# Company Name: Versum Materials Inc
# Could not find ticker for Versum Materials Inc. Marking row for deletion.
# Processing Zooplus SE with transaction date 2021-09-02
# Company Name: Zooplus SE
# PARTIAL_TICKER: ZO1
# Could not find ticker for Zooplus SE. Marking row for deletion.
# Processing Altium Ltd with transaction date 2021-06-06
# Company Name: Altium Ltd
# PARTIAL_TICKER: <NA>
# Could not find ticker for Altium Ltd. Marking row for deletion.
# Processing Garrett Motion Inc with transaction date 2020-10-19
# Company Name: Garrett Motion Inc
# PARTIAL_TICKER: GTX
# Found ticker: GTX for Garrett Motion Inc
# Retrieved cash flow data for GTX: [386000000, 166000000, 490000000, 317000000]
# Error processing Garrett Motion Inc: Unable to resolve all requested identifiers in ['GTX'].
# Processing Healthscope Pty Ltd with transaction date 2018-10-23
# Company Name: Healthscope Pty Ltd
# PARTIAL_TICKER: HSO
# Could not find ticker for Healthscope Pty Ltd. Marking row for deletion.
# Processing SPX FLOW Inc with transaction date 2021-07-19
# Company Name: SPX FLOW Inc
# Could not find ticker for SPX FLOW Inc. Marking row for deletion.
# Processing Waters Corp with transaction date 2019-01-21
# Company Name: Waters Corp
# PARTIAL_TICKER: WAT
# Found ticker: WAT for Waters Corp
# Retrieved cash flow data for WAT: [703638000, 694265000, 647256000, 824523000, 838178000]
# WAT                  EBITDA - Actual
# Date
# 2018-01-23 06:50:00        804201000
# Most recent EBITDA for WAT: 804201000
# Exit multiple for WAT: 12.0
# 0.03695002904709913
# Computed retroactive DCF valuation for WAT: 8775486132.218983
# Processing Osram Licht AG with transaction date 2019-02-13
# Company Name: Osram Licht AG
# PARTIAL_TICKER: OSR
# Found ticker: OSR.MI for Osram Licht AG
# Retrieved cash flow data for OSR.MI: [-31000000, 148000000]
# OSR.MI               EBITDA - Actual
# Date
# 2017-11-07 06:25:00        621000000
# 2018-11-07 08:47:00        477000000
# Most recent EBITDA for OSR.MI: 477000000
# Exit multiple for OSR.MI: 7.0
# -5.774193548387097
# Computed retroactive DCF valuation for OSR.MI: 2853636363.636363
# Processing Aerojet Rocketdyne Holdings Inc with transaction date 2020-12-20
# Company Name: Aerojet Rocketdyne Holdings Inc
# Could not find ticker for Aerojet Rocketdyne Holdings Inc. Marking row for deletion.
# Processing Playtech PLC with transaction date 2021-10-17
# Company Name: Playtech PLC
# PARTIAL_TICKER: PTEC
# Found ticker: PTEC.L for Playtech PLC
# Retrieved cash flow data for PTEC.L: [115067000, 855800000, 213400000]
# PTEC.L               EBITDA - Actual
# Date
# 2020-02-27 07:00:00        383066000
# 2021-03-11 07:00:00        253555000
# Most recent EBITDA for PTEC.L: 253555000
# Exit multiple for PTEC.L: 8.5
# 3.5621865503953734
# Computed retroactive DCF valuation for PTEC.L: 2591456476.333583
# Processing Spring Real Estate Investment Trust with transaction date 2018-09-26
# Company Name: Spring Real Estate Investment Trust
# PARTIAL_TICKER: 1426
# Found ticker: 1426.HK for Spring Real Estate Investment Trust
# Retrieved cash flow data for 1426.HK: [<NA>, <NA>, <NA>, -189924000, 509950000, <NA>]
# 1426.HK              EBITDA - Actual
# Date
# 2017-03-23 05:41:00         42196000
# Most recent EBITDA for 1426.HK: 42196000
# Exit multiple for 1426.HK: 16.0
# <NA>
# Computed retroactive DCF valuation for 1426.HK: <NA>
# Processing Monmouth Real Estate Investment Corp with transaction date 2021-07-12
# Company Name: Monmouth Real Estate Investment Corp
# Could not find ticker for Monmouth Real Estate Investment Corp. Marking row for deletion.
# Processing Columbia Property Trust Inc with transaction date 2021-03-15
# Company Name: Columbia Property Trust Inc
# Could not find ticker for Columbia Property Trust Inc. Marking row for deletion.
# Processing Monmouth Real Estate Investment Corp with transaction date 2021-05-04
# Company Name: Monmouth Real Estate Investment Corp
# Could not find ticker for Monmouth Real Estate Investment Corp. Marking row for deletion.
# Processing American Equity Investment Life Holding Co with transaction date 2020-10-01
# Company Name: American Equity Investment Life Holding Co
# Could not find ticker for American Equity Investment Life Holding Co. Marking row for deletion.
# Processing Tus Environmental Science and Technology Development Co Ltd with transaction date 2021-01-11
# Company Name: Tus Environmental Science and Technology Development Co Ltd
# PARTIAL_TICKER: 000826
# Could not find ticker for Tus Environmental Science and Technology Development Co Ltd. Marking row for deletion.
# Processing Bumrungrad Hospital PCL with transaction date 2020-02-27
# Company Name: Bumrungrad Hospital PCL
# PARTIAL_TICKER: BH
# Found ticker: BH for Bumrungrad Hospital PCL
# Retrieved cash flow data for BH: [74958000, -5767000, 65528000, 4138000]
# BH                   EBITDA - Actual
# Date
# 2019-02-25 07:38:00         15546000
# Most recent EBITDA for BH: 15546000
# Exit multiple for BH: 12.0
# -4.807687678724874
# Computed retroactive DCF valuation for BH: 242853512.7382009
# Processing Cubic Corp with transaction date 2021-03-22
# Company Name: Cubic Corp
# Could not find ticker for Cubic Corp. Marking row for deletion.
# Processing Sanderson Farms Inc with transaction date 2020-10-29
# Company Name: Sanderson Farms Inc
# Could not find ticker for Sanderson Farms Inc. Marking row for deletion.
# Processing Marston's PLC with transaction date 2021-01-29
# Company Name: Marston's PLC
# Could not find ticker for Marston's PLC. Marking row for deletion.
# Processing Cineplex Inc with transaction date 2019-12-16
# Company Name: Cineplex Inc
# PARTIAL_TICKER: CGX
# Found ticker: CGX.TO for Cineplex Inc
# Retrieved cash flow data for CGX.TO: [217311000, 311345000, -370762000, -33433000, 173299000]
# CGX.TO               EBITDA - Actual
# Date
# 2018-02-22 06:15:00        235929000
# 2019-02-15 06:15:00        253875000
# Most recent EBITDA for CGX.TO: 253875000
# Exit multiple for CGX.TO: 8.0
# -1.549728524138704
# Computed retroactive DCF valuation for CGX.TO: 1522167456.3337076
# Processing Raspadskaya PAO with transaction date 2021-01-26
# Company Name: Raspadskaya PAO
# PARTIAL_TICKER: RASP
# Could not find ticker for Raspadskaya PAO. Marking row for deletion.
# Processing Texas Capital Bancshares Inc with transaction date 2019-12-09
# Company Name: Texas Capital Bancshares Inc
# PARTIAL_TICKER: TCBI
# Found ticker: TCBI.O for Texas Capital Bancshares Inc
# Retrieved cash flow data for TCBI.O: [315659000, 339532000, 131464000, 328624000, 360512000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Texas Capital Bancshares Inc: index -1 is out of bounds for axis 0 with size 0
# Processing Arriver Holdco Inc with transaction date 2021-07-22
# Company Name: Arriver Holdco Inc
# Could not find ticker for Arriver Holdco Inc. Marking row for deletion.
# Processing Konecranes Abp with transaction date 2020-10-01
# Company Name: Konecranes Abp
# PARTIAL_TICKER: KCR
# Found ticker: KCR.L for Konecranes Abp
# Retrieved cash flow data for KCR.L: [-3537680, -901202, -320644, -102810]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Konecranes Abp: index -1 is out of bounds for axis 0 with size 0
# Processing China Biologic Products Holdings Inc with transaction date 2018-08-17
# Company Name: China Biologic Products Holdings Inc
# Could not find ticker for China Biologic Products Holdings Inc. Marking row for deletion.
# Processing Future Retail Ltd with transaction date 2020-08-29
# Company Name: Future Retail Ltd
# PARTIAL_TICKER: FRETAIL
# Could not find ticker for Future Retail Ltd. Marking row for deletion.
# Processing Monmouth Real Estate Investment Corp with transaction date 2020-12-21
# Company Name: Monmouth Real Estate Investment Corp
# Could not find ticker for Monmouth Real Estate Investment Corp. Marking row for deletion.
# Processing MUFG Pension & Market Services Holdings Ltd with transaction date 2020-12-07
# Company Name: MUFG Pension & Market Services Holdings Ltd
# PARTIAL_TICKER: LNK
# Found ticker: LNK.AX for MUFG Pension & Market Services Holdings Ltd
# Retrieved cash flow data for LNK.AX: [69745000, 916000, 97146000, 85913000]
# LNK.AX               EBITDA - Actual
# Date
# 2019-08-29 04:01:00        356089000
# 2020-08-27 04:08:00        293794000
# Most recent EBITDA for LNK.AX: 293794000
# Exit multiple for LNK.AX: 7.0
# 34.55389216947195
# Computed retroactive DCF valuation for LNK.AX: 1600485318.6257765
# Processing MK Lenta PAO with transaction date 2019-04-05
# Company Name: MK Lenta PAO
# PARTIAL_TICKER: LNTA
# Could not find ticker for MK Lenta PAO. Marking row for deletion.
# Processing Keppel Ltd with transaction date 2019-10-21
# Company Name: Keppel Ltd
# PARTIAL_TICKER: BN4
# Could not find ticker for Keppel Ltd. Marking row for deletion.
# Processing Dye & Durham Ltd with transaction date 2021-05-31
# Company Name: Dye & Durham Ltd
# PARTIAL_TICKER: DND
# Found ticker: DND.TO for Dye & Durham Ltd
# Retrieved cash flow data for DND.TO: [8562000, 140773000, -20588000]
# DND.TO               EBITDA - Actual
# Date
# 2020-09-22 07:08:00         36685000
# Most recent EBITDA for DND.TO: 36685000
# Exit multiple for DND.TO: 12.5
# 8.806461603227879
# Computed retroactive DCF valuation for DND.TO: 453181682.9451539
# Processing Vocus Group Ltd with transaction date 2019-05-27
# Company Name: Vocus Group Ltd
# PARTIAL_TICKER: VOC
# Found ticker: VOC for Vocus Group Ltd
# No cash flow data found for ticker VOC. Marking row for deletion.
# Processing Cincinnati Bell Inc with transaction date 2019-12-23
# Company Name: Cincinnati Bell Inc
# Could not find ticker for Cincinnati Bell Inc. Marking row for deletion.
# Processing Spire Healthcare Group PLC with transaction date 2021-05-26
# Company Name: Spire Healthcare Group PLC
# PARTIAL_TICKER: SPI
# Found ticker: SPI.O for Spire Healthcare Group PLC
# Retrieved cash flow data for SPI.O: [-2696000, -37559000, -29561000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Spire Healthcare Group PLC: index -1 is out of bounds for axis 0 with size 0
# Processing MUFG Pension & Market Services Holdings Ltd with transaction date 2020-10-12
# Company Name: MUFG Pension & Market Services Holdings Ltd
# PARTIAL_TICKER: LNK
# Found ticker: LNK.AX for MUFG Pension & Market Services Holdings Ltd
# Retrieved cash flow data for LNK.AX: [69745000, 916000, 97146000, 85913000]
# LNK.AX               EBITDA - Actual
# Date
# 2019-08-29 04:01:00        356089000
# 2020-08-27 04:08:00        293794000
# Most recent EBITDA for LNK.AX: 293794000
# Exit multiple for LNK.AX: 7.0
# 34.55389216947195
# Computed retroactive DCF valuation for LNK.AX: 1600485318.6257765
# Processing Vocus Group Ltd with transaction date 2019-06-11
# Company Name: Vocus Group Ltd
# PARTIAL_TICKER: VOC
# Found ticker: VOC for Vocus Group Ltd
# No cash flow data found for ticker VOC. Marking row for deletion.
# Processing Navient Corp with transaction date 2019-02-18
# Company Name: Navient Corp
# PARTIAL_TICKER: NAVI
# Found ticker: NAVI.O for Navient Corp
# No cash flow data found for ticker NAVI.O. Marking row for deletion.
# Processing Metropole Television SA with transaction date 2021-05-17
# Company Name: Metropole Television SA
# PARTIAL_TICKER: MMT
# Found ticker: MMT for Metropole Television SA
# No cash flow data found for ticker MMT. Marking row for deletion.
# Processing Invesco Office J-Reit Inc with transaction date 2021-04-02
# Company Name: Invesco Office J-Reit Inc
# PARTIAL_TICKER: 3298
# Could not find ticker for Invesco Office J-Reit Inc. Marking row for deletion.
# Processing Ampol Ltd with transaction date 2020-01-08
# Company Name: Ampol Ltd
# PARTIAL_TICKER: ALD
# Found ticker: ALD.AX for Ampol Ltd
# Retrieved cash flow data for ALD.AX: [771177000, -57500000, 924600000, 1217000000]
# ALD.AX               EBITDA - Actual
# Date
# 2018-02-26 12:30:00       1164163000
# 2019-02-26 03:32:00       1082000000
# Most recent EBITDA for ALD.AX: 1082000000
# Exit multiple for ALD.AX: 5.5
# -6.100639520444815
# Computed retroactive DCF valuation for ALD.AX: 6244055451.813398
# Processing Inmarsat Group Holdings Ltd with transaction date 2018-06-08
# Company Name: Inmarsat Group Holdings Ltd
# PARTIAL_TICKER: ISAT
# Found ticker: ISAT.F for Inmarsat Group Holdings Ltd
# Retrieved cash flow data for ISAT.F: [10154741000000, 6163974000000, 11200198000000, 9381255000000, 17064144000000, 19073361000000]
# ISAT.F               EBITDA - Actual
# Date
# 2017-03-16 04:41:00   12913123000000
# 2018-03-30 22:48:00   12885311000000
# Most recent EBITDA for ISAT.F: 12885311000000
# Error occurred: index 0 is out of bounds for axis 0 with size 0
# Exit multiple for ISAT.F: 8.0
# 0.18850000634421268
# Computed retroactive DCF valuation for ISAT.F: 108697457072779.28
# Processing Healius Ltd with transaction date 2020-02-25
# Company Name: Healius Ltd
# PARTIAL_TICKER: HLS
# Found ticker: HLS.AX for Healius Ltd
# Retrieved cash flow data for HLS.AX: [298100000, 313600000, 570900000, -102800000]
# HLS.AX               EBITDA - Actual
# Date
# 2018-08-20 05:55:00        282200000
# 2019-08-16 03:59:00        236000000
# Most recent EBITDA for HLS.AX: 236000000
# Exit multiple for HLS.AX: 12.0
# 0.03436295457871393
# Computed retroactive DCF valuation for HLS.AX: 2823179495.9360695
# Processing CEVA Logistics AG with transaction date 2018-10-11
# Company Name: CEVA Logistics AG
# Could not find ticker for CEVA Logistics AG. Marking row for deletion.
# Processing Tianqi Lithium Corp with transaction date 2021-01-15
# Company Name: Tianqi Lithium Corp
# PARTIAL_TICKER: 002466
# Could not find ticker for Tianqi Lithium Corp. Marking row for deletion.
# Processing Partner Communications Company Ltd with transaction date 2020-01-29
# Company Name: Partner Communications Company Ltd
# PARTIAL_TICKER: PTNR
# Found ticker: PTNR.O for Partner Communications Company Ltd
# Retrieved cash flow data for PTNR.O: [216159744.18509, 212616018.61037, 265955871.73937, 234346857.91672]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Partner Communications Company Ltd: index -1 is out of bounds for axis 0 with size 0
# Processing Iress Ltd with transaction date 2021-07-29
# Company Name: Iress Ltd
# PARTIAL_TICKER: IRE
# Found ticker: IRE.AX for Iress Ltd
# Retrieved cash flow data for IRE.AX: [98359000, 120776000, 93328000]
# IRE.AX               EBITDA - Actual
# Date
# 2020-02-20 06:40:00        130700000
# 2021-02-18 03:05:00        125489000
# Most recent EBITDA for IRE.AX: 125489000
# Exit multiple for IRE.AX: 12.5
# 0.04584052398151338
# Computed retroactive DCF valuation for IRE.AX: 1437872644.6280987
# Processing Ontex Group NV with transaction date 2018-07-06
# Company Name: Ontex Group NV
# PARTIAL_TICKER: ONTEX
# Found ticker: ONTEX.BR for Ontex Group NV
# Retrieved cash flow data for ONTEX.BR: [182100000, 153900000, 124700000, 140700000, 68200000, -78300000]
# ONTEX.BR             EBITDA - Actual
# Date
# 2017-03-08 06:00:00        248700000
# 2018-03-06 06:05:00        266400000
# Most recent EBITDA for ONTEX.BR: 266400000
# Exit multiple for ONTEX.BR: 10.5
# -0.36033129565359
# Computed retroactive DCF valuation for ONTEX.BR: 2059619488.6882238
# Processing Smurfit Kappa Group PLC with transaction date 2018-03-06
# Company Name: Smurfit Kappa Group PLC
# Could not find ticker for Smurfit Kappa Group PLC. Marking row for deletion.
# Processing Suning.Com Co Ltd with transaction date 2021-02-25
# Company Name: Suning.Com Co Ltd
# PARTIAL_TICKER: 002024
# Could not find ticker for Suning.Com Co Ltd. Marking row for deletion.
# Processing Front Yard Residential Corp with transaction date 2020-02-18
# Company Name: Front Yard Residential Corp
# Could not find ticker for Front Yard Residential Corp. Marking row for deletion.
# Processing RR Donnelley & Sons Co with transaction date 2021-11-03
# Company Name: RR Donnelley & Sons Co
# Could not find ticker for RR Donnelley & Sons Co. Marking row for deletion.
# Processing Apex Group Jersey Ltd with transaction date 2021-05-14
# Company Name: Apex Group Jersey Ltd
# PARTIAL_TICKER: SNN
# Found ticker: SNN for Apex Group Jersey Ltd
# Retrieved cash flow data for SNN: [993000000, 1087000000, 754000000]
# SNN                  EBITDA - Actual
# Date
# 2020-02-20 02:01:00       1522000000
# 2021-02-18 02:00:00       1050000000
# Most recent EBITDA for SNN: 1050000000
# Error occurred: index 0 is out of bounds for axis 0 with size 0
# Exit multiple for SNN: 8.0
# -0.06574151535449158
# Computed retroactive DCF valuation for SNN: 8678610067.61833
# Processing Graincorp Ltd with transaction date 2018-12-03
# Company Name: Graincorp Ltd
# PARTIAL_TICKER: GNC
# Found ticker: GNC.L for Graincorp Ltd
# Retrieved cash flow data for GNC.L: [50600000, 80800000, 46500000, 87300000, 91500000, 99000000]
# GNC.L                EBITDA - Actual
# Date
# 2017-11-28 07:00:00        189700000
# Most recent EBITDA for GNC.L: 189700000
# Exit multiple for GNC.L: 10.5
# 0.2638222329000253
# Computed retroactive DCF valuation for GNC.L: 1444384690.112279
# Processing Vedanta Ltd with transaction date 2020-05-12
# Company Name: Vedanta Ltd
# PARTIAL_TICKER: VEDL
# Found ticker: VEDL.N for Vedanta Ltd
# Retrieved cash flow data for VEDL.N: [832012804.05759, 3083581698.68359]
# Error processing Vedanta Ltd: Unable to resolve all requested identifiers in ['VEDL.N'].
# Processing Neles Oyj with transaction date 2020-07-13
# Company Name: Neles Oyj
# PARTIAL_TICKER: NELES
# Could not find ticker for Neles Oyj. Marking row for deletion.
# Processing Bingo Industries Pty Ltd with transaction date 2021-01-19
# Company Name: Bingo Industries Pty Ltd
# PARTIAL_TICKER: BIN
# Could not find ticker for Bingo Industries Pty Ltd. Marking row for deletion.
# Processing Cardtronics Ltd with transaction date 2020-12-09
# Company Name: Cardtronics Ltd
# PARTIAL_TICKER: <NA>
# Could not find ticker for Cardtronics Ltd. Marking row for deletion.
# Processing Nikola Corp with transaction date 2020-09-08
# Company Name: Nikola Corp
# PARTIAL_TICKER: NKLA
# Found ticker: NKLA.O for Nikola Corp
# Retrieved cash flow data for NKLA.O: [<NA>, -364858000, -682207000, -715373000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Nikola Corp: index -1 is out of bounds for axis 0 with size 0
# Processing Hammerson PLC with transaction date 2018-03-19
# Company Name: Hammerson PLC
# PARTIAL_TICKER: HMSO
# Found ticker: HMSO.L for Hammerson PLC
# Retrieved cash flow data for HMSO.L: [413700000, -173600000, -776100000, -1731900000, -404900000, -160100000]
# HMSO.L               EBITDA - Actual
# Date
# 2017-02-20 07:39:00        302400000
# 2018-02-26 07:00:00        323600000
# Most recent EBITDA for HMSO.L: 323600000
# Exit multiple for HMSO.L: 16.0
# 0.5126847197644666
# Computed retroactive DCF valuation for HMSO.L: 1047450314.7224388
# Processing National Storage REIT with transaction date 2020-02-14
# Company Name: National Storage REIT
# PARTIAL_TICKER: NSR
# Found ticker: NSR.N for National Storage REIT
# Retrieved cash flow data for NSR.N: [<NA>, 27980000, <NA>]
# Error processing National Storage REIT: Unable to resolve all requested identifiers in ['NSR.N'].
# Processing National Storage REIT with transaction date 2020-01-23
# Company Name: National Storage REIT
# PARTIAL_TICKER: NSR
# Found ticker: NSR.N for National Storage REIT
# Retrieved cash flow data for NSR.N: [<NA>, 27980000, <NA>]
# Error processing National Storage REIT: Unable to resolve all requested identifiers in ['NSR.N'].
# Processing National Storage REIT with transaction date 2020-02-18
# Company Name: National Storage REIT
# PARTIAL_TICKER: NSR
# Found ticker: NSR.N for National Storage REIT
# Retrieved cash flow data for NSR.N: [<NA>, 27980000, <NA>]
# Error processing National Storage REIT: Unable to resolve all requested identifiers in ['NSR.N'].
# Processing Unizo Holdings Co Ltd with transaction date 2019-09-27
# Company Name: Unizo Holdings Co Ltd
# PARTIAL_TICKER: 3258
# Could not find ticker for Unizo Holdings Co Ltd. Marking row for deletion.
# Processing Liberbank Extinguida SA with transaction date 2019-02-22
# Company Name: Liberbank Extinguida SA
# Could not find ticker for Liberbank Extinguida SA. Marking row for deletion.
# Processing China Biologic Products Holdings Inc with transaction date 2018-06-18
# Company Name: China Biologic Products Holdings Inc
# Could not find ticker for China Biologic Products Holdings Inc. Marking row for deletion.
# Processing Tikkurila Oyj with transaction date 2021-01-18
# Company Name: Tikkurila Oyj
# PARTIAL_TICKER: TIK1V
# Found ticker: TIK1V.F for Tikkurila Oyj
# Retrieved cash flow data for TIK1V.F: [66023000]
# Error processing Tikkurila Oyj: Unable to resolve all requested identifiers in ['TIK1V.F'].
# Processing LaSalle Hotel Properties with transaction date 2018-05-21
# Company Name: LaSalle Hotel Properties
# Could not find ticker for LaSalle Hotel Properties. Marking row for deletion.
# Processing VCREDIT Holdings Ltd with transaction date 2020-04-05
# Company Name: VCREDIT Holdings Ltd
# PARTIAL_TICKER: 2003
# Found ticker: 2003.T for VCREDIT Holdings Ltd
# Retrieved cash flow data for 2003.T: [4756000000, 4837000000, 5016000000, 5402000000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing VCREDIT Holdings Ltd: index -1 is out of bounds for axis 0 with size 0
# Processing Trade Me Group Ltd with transaction date 2018-12-05
# Company Name: Trade Me Group Ltd
# Could not find ticker for Trade Me Group Ltd. Marking row for deletion.
# Processing Centamin PLC with transaction date 2019-12-03
# Company Name: Centamin PLC
# PARTIAL_TICKER: CEY
# Found ticker: CEY.L for Centamin PLC
# Retrieved cash flow data for CEY.L: [262696000, 289104000, 439461000, 293121000, 317544000]
# CEY.L                EBITDA - Actual
# Date
# 2018-01-31 07:00:00        370517000
# 2019-02-25 07:06:00        257934000
# Most recent EBITDA for CEY.L: 257934000
# Exit multiple for CEY.L: 6.0
# 0.12504256594896257
# Computed retroactive DCF valuation for CEY.L: 2166232775.70459
# Processing CSRA Inc with transaction date 2018-03-18
# Company Name: CSRA Inc
# Could not find ticker for CSRA Inc. Marking row for deletion.
# Processing WageWorks Inc with transaction date 2019-08-27
# Company Name: WageWorks Inc
# Could not find ticker for WageWorks Inc. Marking row for deletion.
# Processing Vanquis Banking Group PLC with transaction date 2019-02-22
# Company Name: Vanquis Banking Group PLC
# PARTIAL_TICKER: VANQ
# Found ticker: VANQ.L for Vanquis Banking Group PLC
# Retrieved cash flow data for VANQ.L: [93600000, 117400000, -6200000, 168100000, 110400000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Vanquis Banking Group PLC: index -1 is out of bounds for axis 0 with size 0
# Processing Elementis PLC with transaction date 2020-11-12
# Company Name: Elementis PLC
# PARTIAL_TICKER: ELM
# Found ticker: ELM.L for Elementis PLC
# Retrieved cash flow data for ELM.L: [116500000, -300000, 60400000, 2400000]
# ELM.L                EBITDA - Actual
# Date
# 2019-03-05 07:01:00        177900000
# 2020-03-04 07:00:00        193100000
# Most recent EBITDA for ELM.L: 193100000
# Exit multiple for ELM.L: 6.0
# -68.10342558116767
# Computed retroactive DCF valuation for ELM.L: 944019192.6780956
# Processing Circor International Inc with transaction date 2019-05-21
# Company Name: Circor International Inc
# Could not find ticker for Circor International Inc. Marking row for deletion.
# Processing Healthscope Pty Ltd with transaction date 2018-05-14
# Company Name: Healthscope Pty Ltd
# PARTIAL_TICKER: HSO
# Could not find ticker for Healthscope Pty Ltd. Marking row for deletion.
# Processing Aes Tiete Energia Sa with transaction date 2020-03-02
# Company Name: Aes Tiete Energia Sa
# Could not find ticker for Aes Tiete Energia Sa. Marking row for deletion.
# Processing Norway Royal Salmon ASA with transaction date 2021-08-20
# Company Name: Norway Royal Salmon ASA
# PARTIAL_TICKER: NRS
# Could not find ticker for Norway Royal Salmon ASA. Marking row for deletion.
# Processing Healius Ltd with transaction date 2019-01-03
# Company Name: Healius Ltd
# PARTIAL_TICKER: HLS
# Found ticker: HLS.AX for Healius Ltd
# Retrieved cash flow data for HLS.AX: [122600000, 298100000, 313600000, 570900000, -102800000]
# HLS.AX               EBITDA - Actual
# Date
# 2017-08-18 03:52:00        311200000
# 2018-08-20 05:55:00        282200000
# Most recent EBITDA for HLS.AX: 282200000
# Exit multiple for HLS.AX: 12.0
# 0.5333349359602383
# Computed retroactive DCF valuation for HLS.AX: 3022220141.4458766
# Processing Ranger Oil Corp with transaction date 2018-10-28
# Company Name: Ranger Oil Corp
# Could not find ticker for Ranger Oil Corp. Marking row for deletion.
# Processing Blue Prism Group Ltd with transaction date 2021-08-31
# Company Name: Blue Prism Group Ltd
# PARTIAL_TICKER: PRSM
# Found ticker: PRSM.MI for Blue Prism Group Ltd
# Retrieved cash flow data for PRSM.MI: [-3406666, -5032805, -9731145]
# PRSM.MI              EBITDA - Actual
# Date
# 2020-03-19 09:14:00          1378000
# Most recent EBITDA for PRSM.MI: 1378000
# Error occurred: index 0 is out of bounds for axis 0 with size 0
# Exit multiple for PRSM.MI: 8.0
# 0.6598213948935404
# Computed retroactive DCF valuation for PRSM.MI: -6284970.969196092
# Processing Senior PLC with transaction date 2021-05-28
# Company Name: Senior PLC
# PARTIAL_TICKER: SNR
# Found ticker: SNR for Senior PLC
# No cash flow data found for ticker SNR. Marking row for deletion.
# Processing Manulife Financial Corp with transaction date 2019-02-19
# Company Name: Manulife Financial Corp
# PARTIAL_TICKER: MFC
# Found ticker: MFC for Manulife Financial Corp
# Retrieved cash flow data for MFC: [<NA>, <NA>, 6061000000, 7226000000, -1720000000]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Manulife Financial Corp: index -1 is out of bounds for axis 0 with size 0
# Processing Abertis Infraestructuras SA with transaction date 2017-10-18
# Company Name: Abertis Infraestructuras SA
# PARTIAL_TICKER: ABE
# Found ticker: ABE.AX for Abertis Infraestructuras SA
# Retrieved cash flow data for ABE.AX: [<NA>, <NA>, -3587549, -860510, -300615, -3575346, -4712622]
# Empty DataFrame
# Columns: [EBITDA - Actual]
# Index: []
# Error processing Abertis Infraestructuras SA: index -1 is out of bounds for axis 0 with size 0
# Processing Gannett Media Corp with transaction date 2019-01-14
# Company Name: Gannett Media Corp
# ...
# Company Name: J Way Co Ltd
# Could not find ticker for J Way Co Ltd. Marking row for deletion.
# Processing Hampton Sky Realty Ltd with transaction date 2021-02-15
# Company Name: Hampton Sky Realty Ltd
# Could not find ticker for Hampton Sky Realty Ltd. Marking row for deletion.
# Processing Cozum Yatirim Holding AS with transaction date 2020-05-14
# Company Name: Cozum Yatirim Holding AS
# Could not find ticker for Cozum Yatirim Holding AS. Marking row for deletion.
# Processing Netmedia SA with transaction date 2018-11-28
# Company Name: Netmedia SA
# Could not find ticker for Netmedia SA. Marking row for deletion.
# Processing J Way Co Ltd with transaction date 2020-06-19
# Company Name: J Way Co Ltd
# Could not find ticker for J Way Co Ltd. Marking row for deletion.
# Processing G.U.On Co Ltd with transaction date 2018-09-04
# Company Name: G.U.On Co Ltd
# Could not find ticker for G.U.On Co Ltd. Marking row for deletion.
# Processing Xtglobal Infotech Ltd with transaction date 2019-09-05
# Company Name: Xtglobal Infotech Ltd
# Could not find ticker for Xtglobal Infotech Ltd. Marking row for deletion.
# Processing Watta Holding Bhd with transaction date 2020-08-05
# Company Name: Watta Holding Bhd
# Could not find ticker for Watta Holding Bhd. Marking row for deletion.
# Processing Woosung I.B. Co Ltd with transaction date 2018-08-27
# Company Name: Woosung I.B. Co Ltd
# Could not find ticker for Woosung I.B. Co Ltd. Marking row for deletion.
# Processing Sovran White International Ltd with transaction date 2018-12-12
# Company Name: Sovran White International Ltd
# Could not find ticker for Sovran White International Ltd. Marking row for deletion.
# Processing e-Muzyka SA with transaction date 2020-06-29
# Company Name: e-Muzyka SA
# Could not find ticker for e-Muzyka SA. Marking row for deletion.
# Processing Cuda Oil and Gas Inc with transaction date 2018-07-03
# Company Name: Cuda Oil and Gas Inc
# Could not find ticker for Cuda Oil and Gas Inc. Marking row for deletion.
# Processing Korea Cable TV Chung Buk System Co Ltd with transaction date 2018-07-27
# Company Name: Korea Cable TV Chung Buk System Co Ltd
# Could not find ticker for Korea Cable TV Chung Buk System Co Ltd. Marking row for deletion.
# Processing Sports Seoul Co Ltd with transaction date 2018-12-24
# Company Name: Sports Seoul Co Ltd
# Could not find ticker for Sports Seoul Co Ltd. Marking row for deletion.
# Processing Trescon Ltd with transaction date 2018-09-21
# Company Name: Trescon Ltd
# Could not find ticker for Trescon Ltd. Marking row for deletion.
# Processing SG Finserve Ltd with transaction date 2021-08-20
# Company Name: SG Finserve Ltd
# Could not find ticker for SG Finserve Ltd. Marking row for deletion.
# Processing We & Win Development Co Ltd with transaction date 2018-11-07
# Company Name: We & Win Development Co Ltd
# Could not find ticker for We & Win Development Co Ltd. Marking row for deletion.
# Processing CosNine Co Ltd with transaction date 2018-09-14
# Company Name: CosNine Co Ltd
# Could not find ticker for CosNine Co Ltd. Marking row for deletion.
# Processing Y&Next Inc with transaction date 2020-12-14
# Company Name: Y&Next Inc
# Could not find ticker for Y&Next Inc. Marking row for deletion.
# Processing Taiyo Bussan Kaisha Ltd with transaction date 2020-09-11
# Company Name: Taiyo Bussan Kaisha Ltd
# Could not find ticker for Taiyo Bussan Kaisha Ltd. Marking row for deletion.
# Processing Welkeeps Hitech Co Ltd with transaction date 2019-12-04
# Company Name: Welkeeps Hitech Co Ltd
# Could not find ticker for Welkeeps Hitech Co Ltd. Marking row for deletion.
# Processing Welkeeps Hitech Co Ltd with transaction date 2019-12-04
# Company Name: Welkeeps Hitech Co Ltd
# Could not find ticker for Welkeeps Hitech Co Ltd. Marking row for deletion.
# Processing Arteria SA with transaction date 2021-01-25
# Company Name: Arteria SA
# Could not find ticker for Arteria SA. Marking row for deletion.
# Processing Keybridge Capital Ltd with transaction date 2020-06-01
# Company Name: Keybridge Capital Ltd
# Could not find ticker for Keybridge Capital Ltd. Marking row for deletion.
# Processing Stamper Oil & Gas Corp with transaction date 2021-03-09
# Company Name: Stamper Oil & Gas Corp
# Could not find ticker for Stamper Oil & Gas Corp. Marking row for deletion.
# Processing Canopy Finance Ltd with transaction date 2021-03-17
# Company Name: Canopy Finance Ltd
# Could not find ticker for Canopy Finance Ltd. Marking row for deletion.
# Processing LaFleur Minerals Inc with transaction date 2020-10-06
# Company Name: LaFleur Minerals Inc
# Could not find ticker for LaFleur Minerals Inc. Marking row for deletion.
# Processing Xuzhou Handler Special Vehicle Co Ltd with transaction date 2018-06-25
# Company Name: Xuzhou Handler Special Vehicle Co Ltd
# Could not find ticker for Xuzhou Handler Special Vehicle Co Ltd. Marking row for deletion.
# Processing Thai Nguyen Water JSC with transaction date 2019-09-03
# Company Name: Thai Nguyen Water JSC
# Could not find ticker for Thai Nguyen Water JSC. Marking row for deletion.
# Processing Kemimedi Co Ltd with transaction date 2018-10-24
# Company Name: Kemimedi Co Ltd
# Could not find ticker for Kemimedi Co Ltd. Marking row for deletion.
# Processing Tianjin Chase Sun Pharmaceutical Co Ltd with transaction date 2018-06-06
# Company Name: Tianjin Chase Sun Pharmaceutical Co Ltd
# Could not find ticker for Tianjin Chase Sun Pharmaceutical Co Ltd. Marking row for deletion.
# Processing Gratomic Inc with transaction date 2019-05-21
# Company Name: Gratomic Inc
# Could not find ticker for Gratomic Inc. Marking row for deletion.
# Processing Westward Gold Inc with transaction date 2020-03-11
# Company Name: Westward Gold Inc
# Could not find ticker for Westward Gold Inc. Marking row for deletion.
# Processing Korea Cable TV Chung Buk System Co Ltd with transaction date 2018-07-18
# Company Name: Korea Cable TV Chung Buk System Co Ltd
# Could not find ticker for Korea Cable TV Chung Buk System Co Ltd. Marking row for deletion.
# Processing Belships ASA with transaction date 2018-06-13
# Company Name: Belships ASA
# Could not find ticker for Belships ASA. Marking row for deletion.
# Processing Kumbhat Financial Services Ltd with transaction date 2021-03-31
# Company Name: Kumbhat Financial Services Ltd
# Could not find ticker for Kumbhat Financial Services Ltd. Marking row for deletion.
# Processing Kemimedi Co Ltd with transaction date 2018-08-27
# Company Name: Kemimedi Co Ltd
# Could not find ticker for Kemimedi Co Ltd. Marking row for deletion.
# Processing Logis Mon Inc with transaction date 2018-08-28
# Company Name: Logis Mon Inc
# Could not find ticker for Logis Mon Inc. Marking row for deletion.
# Processing BWX Ltd with transaction date 2018-05-21
# Company Name: BWX Ltd
# Could not find ticker for BWX Ltd. Marking row for deletion.
# Processing Solis Minerals Ltd with transaction date 2020-01-31
# Company Name: Solis Minerals Ltd
# Could not find ticker for Solis Minerals Ltd. Marking row for deletion.
# Processing Sixty North Gold Mining Ltd with transaction date 2020-12-07
# Company Name: Sixty North Gold Mining Ltd
# Could not find ticker for Sixty North Gold Mining Ltd. Marking row for deletion.
# Processing Santa Rosa Resources Corp with transaction date 2020-10-21
# Company Name: Santa Rosa Resources Corp
# Could not find ticker for Santa Rosa Resources Corp. Marking row for deletion.
# Processing Mongolia Growth Group Ltd with transaction date 2020-03-16
# Company Name: Mongolia Growth Group Ltd
# Could not find ticker for Mongolia Growth Group Ltd. Marking row for deletion.
# Processing Opawica Explorations Inc with transaction date 2020-01-30
# Company Name: Opawica Explorations Inc
# Could not find ticker for Opawica Explorations Inc. Marking row for deletion.
# Processing ChangYuan Technology Group Ltd with transaction date 2018-05-16
# Company Name: ChangYuan Technology Group Ltd
# Could not find ticker for ChangYuan Technology Group Ltd. Marking row for deletion.
# Processing Orestone Mining Corp with transaction date 2020-02-14
# Company Name: Orestone Mining Corp
# Could not find ticker for Orestone Mining Corp. Marking row for deletion.
# Processing Lydia Yesil Enerji Kaynaklari AS with transaction date 2020-06-03
# Company Name: Lydia Yesil Enerji Kaynaklari AS
# Could not find ticker for Lydia Yesil Enerji Kaynaklari AS. Marking row for deletion.
# Processing SH&L Inc with transaction date 2018-07-23
# Company Name: SH&L Inc
# Could not find ticker for SH&L Inc. Marking row for deletion.
# Processing Waste Energy Corp with transaction date 2020-12-16
# Company Name: Waste Energy Corp
# Could not find ticker for Waste Energy Corp. Marking row for deletion.
# Processing Wuxi Boton Technology Ltd with transaction date 2018-06-19
# Company Name: Wuxi Boton Technology Ltd
# Could not find ticker for Wuxi Boton Technology Ltd. Marking row for deletion.
# Processing Good Spirits Hospitality Ltd with transaction date 2019-01-21
# Company Name: Good Spirits Hospitality Ltd
# Could not find ticker for Good Spirits Hospitality Ltd. Marking row for deletion.
# Processing Blue Cloud Softech Solutions Ltd with transaction date 2019-06-18
# Company Name: Blue Cloud Softech Solutions Ltd
# Could not find ticker for Blue Cloud Softech Solutions Ltd. Marking row for deletion.
# Processing Unilever PLC with transaction date 2017-02-17
# Company Name: Unilever PLC
# Could not find ticker for Unilever PLC. Marking row for deletion.
# Processing Corporate Merchant Bankers Ltd with transaction date 2019-08-09
# Company Name: Corporate Merchant Bankers Ltd
# Could not find ticker for Corporate Merchant Bankers Ltd. Marking row for deletion.
# Processing Thirdwave Financial Intermediaries Ltd with transaction date 2020-07-01
# Company Name: Thirdwave Financial Intermediaries Ltd
# Could not find ticker for Thirdwave Financial Intermediaries Ltd. Marking row for deletion.
# Processing Kelsian Group Ltd with transaction date 2018-05-23
# Company Name: Kelsian Group Ltd
# Could not find ticker for Kelsian Group Ltd. Marking row for deletion.
# Processing Winergys Co Ltd with transaction date 2018-07-13
# Company Name: Winergys Co Ltd
# Could not find ticker for Winergys Co Ltd. Marking row for deletion.
# Processing Step Two Corporation Ltd with transaction date 2019-12-04
# Company Name: Step Two Corporation Ltd
# Could not find ticker for Step Two Corporation Ltd. Marking row for deletion.
# Processing Korea Cable TV Chung Buk System Co Ltd with transaction date 2018-07-27
# Company Name: Korea Cable TV Chung Buk System Co Ltd
# Could not find ticker for Korea Cable TV Chung Buk System Co Ltd. Marking row for deletion.
# Processing Thirdwave Financial Intermediaries Ltd with transaction date 2020-07-01
# Company Name: Thirdwave Financial Intermediaries Ltd
# Could not find ticker for Thirdwave Financial Intermediaries Ltd. Marking row for deletion.
# Processing Virya Resources Ltd with transaction date 2021-06-01
# Company Name: Virya Resources Ltd
# Could not find ticker for Virya Resources Ltd. Marking row for deletion.
# Processing AREV Life Sciences Global Corp with transaction date 2020-07-20
# Company Name: AREV Life Sciences Global Corp
# Could not find ticker for AREV Life Sciences Global Corp. Marking row for deletion.
# Processing Logis Mon Inc with transaction date 2019-08-02
# Company Name: Logis Mon Inc
# Could not find ticker for Logis Mon Inc. Marking row for deletion.
# Processing Sparc Electrex Ltd with transaction date 2021-05-31
# Company Name: Sparc Electrex Ltd
# Could not find ticker for Sparc Electrex Ltd. Marking row for deletion.
# Processing Sindu Valley Technologies Ltd with transaction date 2020-12-01
# Company Name: Sindu Valley Technologies Ltd
# Could not find ticker for Sindu Valley Technologies Ltd. Marking row for deletion.
# Processing Ace Engitech Ltd with transaction date 2020-10-26
# Company Name: Ace Engitech Ltd
# Could not find ticker for Ace Engitech Ltd. Marking row for deletion.
# Processing Tetraphase Pharmaceuticals Inc with transaction date 2020-03-16
# Company Name: Tetraphase Pharmaceuticals Inc
# Could not find ticker for Tetraphase Pharmaceuticals Inc. Marking row for deletion.
# Processing Youzan Technology Ltd with transaction date 2021-02-28
# Company Name: Youzan Technology Ltd
# Could not find ticker for Youzan Technology Ltd. Marking row for deletion.
# Updated deals DataFrame:
#                                 AcquirerName  \
# 2   ['Hong Kong Exchanges and Clearing Ltd']
# 3                    ['Xerox Holdings Corp']
# 6                                ['Aon PLC']
# 7                            ['Unilever NV']
# 10                     ['Barrick Gold Corp']
#
#                              TargetName TransactionAnnouncementDate  \
# 2   ['London Stock Exchange Group PLC']                  2019-09-11
# 3                            ['HP Inc']                  2019-11-06
# 6          ['Willis Towers Watson PLC']                  2020-03-09
# 7                      ['Unilever PLC']                  2018-03-15
# 10              ['Newmont Corporation']                  2019-02-22
#
#     PercentageOfSharesAcquired                       AcquirerRegion  \
# 2                            0  Asia Pacific Excluding Central Asia
# 3                            0                             Americas
# 6                            0                               Europe
# 7                            0                               Europe
# 10                           0                             Americas
#
#    TargetRegion  PricePerShare CurrencyCodeOfTransaction  \
# 2        Europe        103.287                       STG
# 3      Americas         23.938                        US
# 6        Europe        234.155                       STG
# 7        Europe         53.695                       STG
# 10     Americas         44.014                        US
#
#                                           DealPurpose FormOfTransactionName  \
# 2   ['Expand presence in new/foreign markets', 'Cr...                Merger
# 3   ['Strengthen existing operations/expand presen...                Merger
# 6   ['Concentrate on core businesses/assets', 'Cre...                Merger
# 7   ['Strengthen existing operations/expand presen...                Merger
# 10  ['Create synergies, eliminate duplicate servic...                Merger
#
#     ... RatioOfTransactionValueToNetIncome  RatioOfTransactionValueToCashFlow  \
# 2   ...                            110.412                             51.970
# 3   ...                             11.742                              6.804
# 6   ...                             29.339                             14.790
# 7   ...                              8.013                              4.879
# 10  ...                             86.512                              9.793
#
#    RatioOfTransactionValueToSales RatioOfRankvalueToNetIncome  \
# 2                          25.666                     110.412
# 3                           0.594                      11.961
# 6                           3.389                      29.339
# 7                           0.881                      11.094
# 10                          3.232                      89.523
#
#    RatioOfRankvalueToCashFlow RatioOfRankvalueToSales  \
# 2                      51.970                  25.666
# 3                       6.930                   0.606
# 6                      14.790                   3.389
# 7                       6.755                   1.220
# 10                     10.134                   3.345
#
#    TransactionValueIncludingNetDebtOfTarget TransactionEffectiveDate  Ticker  \
# 2                                 37259.153               2019-09-11  LSEG.L
# 3                                 35524.904               2019-11-06     HPQ
# 6                                 30140.582               2020-03-09   WTW.O
# 7                                 91563.677               2018-03-15  ULVR.L
# 10                                24260.818               2019-02-22     NEM
#
#     RetroactiveDCFValuation
# 2        10522453570.608065
# 3        53177947855.027275
# 6        18538970698.722759
# 7       103996629390.689865
# 10       21815840075.504028
#
# [5 rows x 30 columns]

# %%
deals_df.to_csv('updated_acquisition_deals.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[337], line 1
# ----> 1 deals_df.to_csv('updated_acquisition_deals.csv', index=False)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3902, in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3797 @final
#    3798 @deprecate_nonkeyword_arguments(
#    3799     version="3.0", allowed_args=["self", "path_or_buf"], name="to_csv"
#    (...)
#    3827     storage_options: StorageOptions | None = None,
#    3828 ) -> str | None:
#    3829     r"""
#    3830     Write object to a comma-separated values (csv) file.
#    3831
#    3832     Parameters
#    3833     ----------
#    3834     path_or_buf : str, path object, file-like object, or None, default None
#    3835         String, path object (implementing os.PathLike[str]), or file-like
#    3836         object implementing a write() function. If None, the result is
#    3837         returned as a string. If a non-binary file object is passed, it should
#    3838         be opened with `newline=''`, disabling universal newlines. If a binary
#    3839         file object is passed, `mode` might need to contain a `'b'`.
#    3840     sep : str, default ','
#    3841         String of length 1. Field delimiter for the output file.
#    3842     na_rep : str, default ''
#    3843         Missing data representation.
#    3844     float_format : str, Callable, default None
#    3845         Format string for floating point numbers. If a Callable is given, it takes
#    3846         precedence over other numeric formatting parameters, like decimal.
#    3847     columns : sequence, optional
#    3848         Columns to write.
#    3849     header : bool or list of str, default True
#    3850         Write out the column names. If a list of strings is given it is
#    3851         assumed to be aliases for the column names.
#    3852     index : bool, default True
#    3853         Write row names (index).
#    3854     index_label : str or sequence, or False, default None
#    3855         Column label for index column(s) if desired. If None is given, and
#    3856         `header` and `index` are True, then the index names are used. A
#    3857         sequence should be given if the object uses MultiIndex. If
#    3858         False do not print fields for index names. Use index_label=False
#    3859         for easier importing in R.
#    3860     mode : {{'w', 'x', 'a'}}, default 'w'
#    3861         Forwarded to either `open(mode=)` or `fsspec.open(mode=)` to control
#    3862         the file opening. Typical values include:
#    3863
#    3864         - 'w', truncate the file first.
#    3865         - 'x', exclusive creation, failing if the file already exists.
#    3866         - 'a', append to the end of file if it exists.
#    3867
#    3868     encoding : str, optional
#    3869         A string representing the encoding to use in the output file,
#    3870         defaults to 'utf-8'. `encoding` is not supported if `path_or_buf`
#    3871         is a non-binary file object.
#    3872     {compression_options}
#    3873
#    3874            May be a dict with key 'method' as compression mode
#    3875            and other entries as additional compression options if
#    3876            compression mode is 'zip'.
#    3877
#    3878            Passing compression options as keys in dict is
#    3879            supported for compression modes 'gzip', 'bz2', 'zstd', and 'zip'.
#    3880     quoting : optional constant from csv module
#    3881         Defaults to csv.QUOTE_MINIMAL. If you have set a `float_format`
#    3882         then floats are converted to strings and thus csv.QUOTE_NONNUMERIC
#    3883         will treat them as non-numeric.
#    3884     quotechar : str, default '\"'
#    3885         String of length 1. Character used to quote fields.
#    3886     lineterminator : str, optional
#    3887         The newline character or character sequence to use in the output
#    3888         file. Defaults to `os.linesep`, which depends on the OS in which
#    3889         this method is called ('\\n' for linux, '\\r\\n' for Windows, i.e.).
#    3890
#    3891         .. versionchanged:: 1.5.0
#    3892
#    3893             Previously was line_terminator, changed for consistency with
#    3894             read_csv and the standard library 'csv' module.
#    3895
#    3896     chunksize : int or None
#    3897         Rows to write at a time.
#    3898     date_format : str, default None
#    3899         Format string for datetime objects.
#    3900     doublequote : bool, default True
#    3901         Control quoting of `quotechar` inside a field.
# -> 3902     escapechar : str, default None
#    3903         String of length 1. Character used to escape `sep` and `quotechar`
#    3904         when appropriate.
#    3905     decimal : str, default '.'
#    3906         Character recognized as decimal separator. E.g. use ',' for
#    3907         European data.
#    3908     errors : str, default 'strict'
#    3909         Specifies how encoding and decoding errors are to be handled.
#    3910         See the errors argument for :func:`open` for a full list
#    3911         of options.
#    3912
#    3913     {storage_options}
#    3914
#    3915     Returns
#    3916     -------
#    3917     None or str
#    3918         If path_or_buf is None, returns the resulting csv format as a
#    3919         string. Otherwise returns None.
#    3920
#    3921     See Also
#    3922     --------
#    3923     read_csv : Load a CSV file into a DataFrame.
#    3924     to_excel : Write DataFrame to an Excel file.
#    3925
#    3926     Examples
#    3927     --------
#    3928     Create 'out.csv' containing 'df' without indices
#    3929
#    3930     >>> df = pd.DataFrame({{'name': ['Raphael', 'Donatello'],
#    3931     ...                    'mask': ['red', 'purple'],
#    3932     ...                    'weapon': ['sai', 'bo staff']}})
#    3933     >>> df.to_csv('out.csv', index=False)  # doctest: +SKIP
#    3934
#    3935     Create 'out.zip' containing 'out.csv'
#    3936
#    3937     >>> df.to_csv(index=False)
#    3938     'name,mask,weapon\nRaphael,red,sai\nDonatello,purple,bo staff\n'
#    3939     >>> compression_opts = dict(method='zip',
#    3940     ...                         archive_name='out.csv')  # doctest: +SKIP
#    3941     >>> df.to_csv('out.zip', index=False,
#    3942     ...           compression=compression_opts)  # doctest: +SKIP
#    3943
#    3944     To write a csv file to a new folder or nested folder you will first
#    3945     need to create it using either Pathlib or os:
#    3946
#    3947     >>> from pathlib import Path  # doctest: +SKIP
#    3948     >>> filepath = Path('folder/subfolder/out.csv')  # doctest: +SKIP
#    3949     >>> filepath.parent.mkdir(parents=True, exist_ok=True)  # doctest: +SKIP
#    3950     >>> df.to_csv(filepath)  # doctest: +SKIP
#    3951
#    3952     >>> import os  # doctest: +SKIP
#    3953     >>> os.makedirs('folder/subfolder', exist_ok=True)  # doctest: +SKIP
#    3954     >>> df.to_csv('folder/subfolder/out.csv')  # doctest: +SKIP
#    3955     """
#    3956     df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958     formatter = DataFrameFormatter(
#    3959         frame=df,
#    3960         header=header,
#    (...)
#    3964         decimal=decimal,
#    3965     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/formats/format.py:1125, in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1123 elif isinstance(values.dtype, DatetimeTZDtype):
#    1124     fmt_klass = _Datetime64TZFormatter
# -> 1125     values = cast(DatetimeArray, values)
#    1126 elif lib.is_np_dtype(values.dtype, "m"):
#    1127     fmt_klass = _Timedelta64Formatter
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/formats/csvs.py:24
#      21 import numpy as np
#      23 from pandas._libs import writers as libwriters
# ---> 24 from pandas._typing import SequenceNotStr
#      25 from pandas.util._decorators import cache_readonly
#      27 from pandas.core.dtypes.generic import (
#      28     ABCDatetimeIndex,
#      29     ABCIndex,
#      30     ABCMultiIndex,
#      31     ABCPeriodIndex,
#      32 )
#
# ImportError: cannot import name 'SequenceNotStr' from 'pandas._typing' (/opt/anaconda3/lib/python3.11/site-packages/pandas/_typing.py)

# %%
import csv

# Open a file in write mode
with open('updated_acquisition_deals.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the header
    writer.writerow(deals_df.columns)
    
    # Write the data rows
    writer.writerows(deals_df.values)

# %%
ld.open_session()

gics_df = ld.discovery.search(
            view=ld.discovery.Views.ORGANISATIONS,
            select="GicsName",
            filter=f"CommonName eq 'Entain PLC'",
            top=10000
        )

print(gics_df.iloc[0,0][0])

ld.close_session()
# Out:
# Consumer Discretionary
